# %%
echo "# fotmob" >> README.md
git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/gonzavarela07/fotmob.git
git push -u origin main
# Out:
#   File "C:\Users\gonza\AppData\Local\Temp\ipykernel_19700\2204834828.py", line 1
#     echo "# fotmob" >> README.md
#          ^
# SyntaxError: invalid syntax

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt

# %%
import tweepy
import pandas as pd
import numpy as np
import urllib
from bs4 import BeautifulSoup
import json
import requests
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
k="4Hufq4DEjAts60rcjprzPS0Le"
ks="s4OjpSuZvMjARm4Rfmx3Yre4KgpTu9tc7zxjEwG5eiNwNNZPeE"
a="1262007978359742464-nP9GPBbEkQZyV6hc5kvkgKZPnhOA8u"
asa="a1qI2aNE5aRpPX9tV3X82hYJaFmdlvrGH9JkaTKC8Hnzr"

# %%
auth=tweepy.OAuthHandler(k,ks)
auth.set_access_token(a,asa)
api=tweepy.API(auth)

# %%
#api.update_status("Hola")

# %%
# liga danesa
equipo_locall=[]
equipo_visitantee=[]
fecha=[]
gol_local=[]
gol_visitante=[]
league=[]
match_idd=[]
m=[]
for i in range(0,300):
    
    
    match_1=3887285
    match=match_1 + i
    URL = f"https://www.fotmob.com/match/{match}"

    r = requests.get(URL)
    html_doc = r.text
    soup = BeautifulSoup(html_doc, "html.parser")
    data_partidos= json.loads(soup.find("script", attrs={"id": "__NEXT_DATA__"}).text)
    try:
        empezo=data_partidos["props"]["pageProps"]["general"]["started"]
    except:
        empezo="la"
    pagina=data_partidos["page"]
    
    if (empezo ==True) and (pagina !='/404') and (data_partidos["props"]["pageProps"]["general"]["leagueName"]=="Superligaen"):
        try:
            stats_general=data_partidos['props']['pageProps']["content"]["stats"]
        except:
             stats_general=data_partidos['props']['pageProps']['initialState']['matchFacts']['data']["content"]["stats"]["stats"]
        try:
            equipo_locall.append(data_partidos['props']['pageProps']["general"]["homeTeam"]["name"])
        except:
            equipo_locall.append(data_partidos['props']['pageProps']['initialState']['matchFacts']['data']["general"]["homeTeam"]["name"])
        try:
            equipo_visitantee.append(data_partidos['props']['pageProps']["general"]["awayTeam"]["name"])
        except:
            equipo_visitantee.append(data_partidos['props']['pageProps']['initialState']['matchFacts']['data']["general"]["awayTeam"]["name"])
        try:
            fecha.append(data_partidos['props']['pageProps']["general"]["matchRound"])
        except:
            fecha.append(data_partidos['props']['pageProps']['initialState']['matchFacts']["data"]["general"]["matchRound"])
        try:
            match_idd.append(data_partidos['props']['pageProps']["general"]["matchId"])
        except:
            match_idd.append(data_partidos['props']['pageProps']['initialState']['matchFacts']["data"]["general"]["matchId"])
        try:
            league.append(data_partidos['props']['pageProps']["general"]["leagueName"])
        except:
            league.append(data_partidos['props']['pageProps']['initialState']['matchFacts']["data"]["general"]["leagueName"])
        try:
            gol_local.append(data_partidos['props']['pageProps']["header"]["teams"][0]["score"])
        except:
            gol_local.append(0)
        try:
            gol_visitante.append(data_partidos['props']['pageProps']["header"]["teams"][1]["score"])
        except:
            gol_visitante.append(0)
        try:
            m.append(data_partidos["props"]["pageProps"]["general"]["matchName"])
        except:
            m.append(0)
        

        col_names_partidos=["Liga","Match Id","Partido","Fecha","Equipo Local","Equipo Visitante","Goles_Local","Goles_Visitante"]


        dinamarca=pd.DataFrame([league,match_idd,m,fecha,equipo_locall,equipo_visitantee,gol_local,gol_visitante],index=col_names_partidos).T
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10968\3970784415.py in <module>
#      25     pagina=data_partidos["page"]
#      26
# ---> 27     if empezo and (pagina != '/404') and data_partidos and data_partidos["props"]["pageProps"]["general"]["leagueName"].str.contains("Superligaen"):
#      28
#      29         try:
#
# AttributeError: 'str' object has no attribute 'str'

# %%
ligas=pd.concat([dinamarca])

# %%
ligas['Resultado'] = ligas.apply(lambda row: [row['Goles_Local'], row['Goles_Visitante']], axis=1)

# %%
ligas
# Out:
#             Liga Match Id                                            Partido  \
# 0    Superligaen  3887285  Midtjylland-vs-Randers FC_Fri, Jul 15, 2022, 1...
# 1    Superligaen  3887286  Viborg-vs-Aalborg BK_Sun, Jul 17, 2022, 12:00 UTC
# 2    Superligaen  3887287   Lyngby-vs-Silkeborg_Sun, Jul 17, 2022, 12:00 UTC
# 3    Superligaen  3887288  FC København-vs-Horsens_Sun, Jul 17, 2022, 14:...
# 4    Superligaen  3887289  Brøndby IF-vs-AGF Aarhus_Sun, Jul 17, 2022, 16...
# 5    Superligaen  3887290  Odense-vs-Nordsjælland_Mon, Jul 18, 2022, 17:0...
# 6    Superligaen  3887291  Midtjylland-vs-Silkeborg_Fri, Jul 22, 2022, 17...
# 7    Superligaen  3887292  AGF Aarhus-vs-Viborg_Sun, Jul 24, 2022, 12:00 UTC
# 8    Superligaen  3887293  Randers FC-vs-Odense_Sun, Jul 24, 2022, 12:00 UTC
# 9    Superligaen  3887294  Brøndby IF-vs-Nordsjælland_Sun, Jul 24, 2022, ...
# 10   Superligaen  3887295  Aalborg BK-vs-FC København_Sun, Jul 24, 2022, ...
# ...

# %%
home_player=[]
away_player=[]
home=[]
away=[]
fecha_L=[]
fecha_V=[]
equipo_L=[]
nombre_local=[]
rating_local=[]
posicion_local=[]
shirt_local=[]
minutes_local=[]
goals_local=[]
assists_local=[]
shots_local=[]
accurate_passes_local=[]
chances_created_local=[]
xg_local=[]
xgot_local=[]
xa_local=[]
blocked_shots_local=[]
touches_local=[]
successful_dribbles_local=[]
passes_into_final_third_local=[]
accurate_crosses_local=[]
accurate_long_balls_local=[]
dispossessed_local=[]
tackles_won_local=[]
clearances_local=[]
headed_clearances_local=[]
interceptions_local=[]
recoveries_local=[]
ground_duels_won_local=[]
aerial_duels_won_local=[]
was_fouled_local=[]
foules_committed_local=[]
penalties_won_local=[]
corner_local=[]
player_id_l=[]



player_id_v=[]
equipo_V=[]
nombre_visitante=[]
rating_visitante=[]
posicion_visitante=[]
shirt_visitante=[]
minutes_visitante=[]
goals_visitante=[]
assists_visitante=[]
shots_visitante=[]
accurate_passes_visitante=[]
chances_created_visitante=[]
xg_visitante=[]
xgot_visitante=[]
xa_visitante=[]
blocked_shots_visitante=[]
touches_visitante=[]
successful_dribbles_visitante=[]
passes_into_final_third_visitante=[]
accurate_crosses_visitante=[]
accurate_long_balls_visitante=[]
dispossessed_visitante=[]
tackles_won_visitante=[]
clearances_visitante=[]
headed_clearances_visitante=[]
interceptions_visitante=[]
recoveries_visitante=[]
ground_duels_won_visitante=[]
aerial_duels_won_visitante=[]
was_fouled_visitante=[]
foules_committed_visitante=[]
penalties_won_visitante=[]
corner_visitante=[]
id_match_L=[]
id_match_V=[]


id_match=[]
team = []
player = []
x = []
y = []
end_x = []
end_y = []
time = []
result = []
situation = []
xG = []
xGOT = []
shot_type=[]
id_team_L=[]
id_team_V=[]
end_z=[]

ball_possesion_general_local=[]
xg_general_local=[]
shots_general_local=[]
big_chances_general_local=[]
big_chances_missed_general_local=[]
accurate_passes_general_local=[]
fouls_committed_general_local=[]
offsides_general_local=[]
corners_general_local=[]
shots_off_target_general_local=[]
shots_on_target_general_local=[]
blocked_shots_general_local=[]
hit_woodwork_general_local=[]
shots_inside_box_general_local=[]
shots_outside_box_general_local=[]
xg_first_half_general_local=[]
xg_second_half_general_local=[]
xg_open_play_general_local=[]
xg_set_play_general_local=[]
xg_on_target_general_local=[]
passes_general_local=[]
passes_own_half_general_local=[]
passes_opposition_half_general_local=[]
passes_accurate_long_balls_general_local=[]
passes_accurate_crosses_general_local=[]
passes_throws_general_local=[]
tackles_won_general_local=[]
interceptions_general_local=[]
blocks_genera_locall=[]
clearances_general_local=[]
keeper_saves_general_local=[]
duels_won_general_local=[]
ground_duels_won_general_local=[]
aerial_duels_won_general_local=[]
successful_dribbles_general_local=[]
yellow_cards_genera_locall=[]
red_cards_general_local=[]

fecha_equipo=[]
local_general=[]
visitante_general=[]
match_id_general=[]

ball_possesion_general_visitante=[]
xg_general_visitante=[]
shots_general_visitante=[]
big_chances_general_visitante=[]
big_chances_missed_general_visitante=[]
accurate_passes_general_visitante=[]
fouls_committed_general_visitante=[]
offsides_general_visitante=[]
corners_general_visitante=[]
shots_off_target_general_visitante=[]
shots_on_target_general_visitante=[]
blocked_shots_general_visitante=[]
hit_woodwork_general_visitante=[]
shots_inside_box_general_visitante=[]
shots_outside_box_general_visitante=[]
xg_first_half_general_visitante=[]
xg_second_half_general_visitante=[]
xg_open_play_general_visitante=[]
xg_set_play_general_visitante=[]
xg_on_target_general_visitante=[]
passes_general_visitante=[]
passes_own_half_general_visitante=[]
passes_opposition_half_general_visitante=[]
passes_accurate_long_balls_general_visitante=[]
passes_accurate_crosses_general_visitante=[]
passes_throws_general_visitante=[]
tackles_won_general_visitante=[]
interceptions_general_visitante=[]
blocks_general_visitante=[]
clearances_general_visitante=[]
keeper_saves_general_visitante=[]
duels_won_general_visitante=[]
ground_duels_won_general_visitante=[]
aerial_duels_won_general_visitante=[]
successful_dribbles_general_visitante=[]
yellow_cards_general_visitante=[]
red_cards_general_visitante=[]

period=[]

#equipo=input()
#filtro=(ligas["Equipo Local"]==equipo) | (ligas["Equipo Visitante"]==equipo)
#elegido=ligas[filtro]

#match_1=3937449
for i in list(ligas["Match Id"]):
    
    #match=match_1 + i
    URL = f"https://www.fotmob.com/match/{i}"

    r = requests.get(URL)
    html_doc = r.text
    soup = BeautifulSoup(html_doc, "html.parser")
    
    data = json.loads(soup.find("script", attrs={"id": "__NEXT_DATA__"}).text)
    try:
        stats_general=data['props']['pageProps']["content"]["stats"]
    except:
         stats_general=data['props']['pageProps']['initialState']['matchFacts']['data']["content"]["stats"]["stats"]
    try:
        team_id_L=data['props']['pageProps']["general"]["homeTeam"]["id"]
    except:
        team_id_L=data['props']['pageProps']['initialState']['matchFacts']['data']["general"]["homeTeam"]["id"]
    
    try:
        team_id_V=data['props']['pageProps']["general"]["awayTeam"]["id"]
    except:
        team_id_V=data['props']['pageProps']['initialState']['matchFacts']['data']["general"]["awayTeam"]["id"]
    

    try:
        equipo_local=data['props']['pageProps']["general"]["homeTeam"]["name"]
    except:
        equipo_local=data['props']['pageProps']['initialState']['matchFacts']['data']["general"]["homeTeam"]["name"]
    
    try:
        equipo_visitante=data['props']['pageProps']["general"]["awayTeam"]["name"]
    except:
        equipo_visitante=data['props']['pageProps']['initialState']['matchFacts']['data']["general"]["awayTeam"]["name"]
    
    try:
        fecha=data['props']['pageProps']["general"]["matchRound"]
    except:
        fecha=data['props']['pageProps']['initialState']['matchFacts']["data"]["general"]["matchRound"]
    
    try:
        match_id=data['props']['pageProps']["general"]["matchId"]
    except:
        match_id=data['props']['pageProps']['initialState']['matchFacts']["data"]["general"]["matchId"]
    
    try:
        shots_data = data['props']['pageProps']["content"]['shotmap']['shots']
    except:
        shots_data = data['props']['pageProps']['initialState']['matchFacts']['data']["content"]['shotmap']['shots']
    
    try:
        stats_individual_local=list(data['props']['pageProps']["content"]["lineup"]["lineup"][0].values())
    except:
        stats_individual_local=list(data['props']['pageProps']['initialState']['matchFacts']['data']["content"]["lineup"]["lineup"][0].values())
    try:    
        stats_individual_visitante=list(data['props']['pageProps']["content"]["lineup"]["lineup"][1].values())
    except:
        stats_individual_visitante=list(data['props']['pageProps']['initialState']['matchFacts']['data']["content"]["lineup"]["lineup"][1].values())

    
    subs_local=stats_individual_local[2]
    titus_local=stats_individual_local[4]
    subs_visitante=stats_individual_visitante[2]
    titus_visitante=stats_individual_visitante[4]
    formacion_local=stats_individual_local[5]
    formacion_visitante=stats_individual_visitante[5]
    


    #nombre_local.append(titus_local[0][0]["name"]["lastName"])
    #shirt_local.append(titus_local[0][0]["shirt"])
    #minutes_local.append(titus_local[0][0]["minutesPlayed"])


    for i in range(0,int(formacion_local[0])):
        id_match_L.append(match_id)
        fecha_L.append(fecha)
        id_team_L.append(team_id_L)
        equipo_L.append(equipo_local)
        home.append("home")
        home_player.append("titular")
        player_id_l.append(titus_local[1][i]["id"])
        nombre_local.append(titus_local[1][i]["name"]["lastName"])
        posicion_local.append(titus_local[1][0]["role"])
        shirt_local.append(titus_local[1][i]["shirt"])
        try:
            minutes_local.append(titus_local[1][i]["minutesPlayed"])
        except:
            minutes_local.append(0)
        try:
            rating_local.append(titus_local[1][i]["stats"][0]["stats"]["FotMob rating"])
        except:
            rating_local.append(0)
        try:
            goals_local.append(titus_local[1][i]["stats"][0]["stats"]["Goals"])
        except:
             goals_local.append(0)
        try:
            assists_local.append(titus_local[1][i]["stats"][0]["stats"]["Assists"])
        except:
            assists_local.append(0)
        try:
            shots_local.append(titus_local[1][i]["stats"][0]["stats"]["Total shots"])
        except:
            shots_local.append(0)
        try:
            accurate_passes_local.append(titus_local[1][i]["stats"][0]["stats"]["Accurate passes"])
        except:
            accurate_passes_local.append(0)
        try:
            chances_created_local.append(titus_local[1][i]["stats"][0]["stats"]["Chances created"])
        except:
            chances_created_local.append(0)
        try:
            xg_local.append(titus_local[1][i]["stats"][0]["stats"]["Expected goals (xG)"])
        except:
            xg_local.append(0)
        try:
            xgot_local.append(titus_local[1][i]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
        except:
            xgot_local.append(0)
        try:
            xa_local.append(titus_local[1][i]["stats"][0]["stats"]['Expected assists (xA)'])
        except:
            xa_local.append(0)
        try:
            blocked_shots_local.append(titus_local[1][i]["stats"][1]["stats"]["Blocked shots"])
        except:
            blocked_shots_local.append(0)
        try:
            touches_local.append(titus_local[1][i]["stats"][1]["stats"]["Touches"])
        except:
            touches_local.append(0)
        try:
            successful_dribbles_local.append(titus_local[1][i]["stats"][1]["stats"]["Successful dribbles"])
        except:
            successful_dribbles_local.append(0)
        try:
            passes_into_final_third_local.append(titus_local[1][i]["stats"][1]["stats"]["Passes into final third"])
        except:
            passes_into_final_third_local.append(0)
        try:
            accurate_crosses_local.append(titus_local[1][i]["stats"][1]["stats"]["Accurate crosses"])
        except:
            accurate_crosses_local.append(0)
        try:
            accurate_long_balls_local.append(titus_local[1][i]["stats"][1]["stats"]["Accurate long balls"])
        except:
            accurate_long_balls_local.append(0)
        try:
            dispossessed_local.append(titus_local[1][i]["stats"][1]["stats"]["Dispossessed"])
        except:
            dispossessed_local.append(0)
        try:
            tackles_won_local.append(titus_local[1][i]["stats"][2]["stats"]["Tackles won"])
        except:
            tackles_won_local.append(0)
        try:
            clearances_local.append(titus_local[1][i]["stats"][2]["stats"]["Clearances"])
        except:
            clearances_local.append(0)
        try:
            headed_clearances_local.append(titus_local[1][i]["stats"][2]["stats"]["Headed clearance"])
        except:
            headed_clearances_local.append(0)
        try:
            interceptions_local.append(titus_local[1][i]["stats"][2]["stats"]["Interceptions"])
        except:
            interceptions_local.append(0)
        try:
            recoveries_local.append(titus_local[1][i]["stats"][2]["stats"]["Recoveries"])
        except:
            recoveries_local.append(0)
        try:
            ground_duels_won_local.append(titus_local[1][i]["stats"][3]["stats"]["Ground duels won"])
        except:
            ground_duels_won_local.append(0)
        try:
            aerial_duels_won_local.append(titus_local[3][z]["stats"][3]["stats"]["Aerial duels won"])
        except:
            aerial_duels_won_local.append(0)
        try:
            was_fouled_local.append(titus_local[1][i]["stats"][3]["stats"]["Was fouled"])
        except:
            was_fouled_local.append(0)
        try:
            foules_committed_local.append(titus_local[1][i]["stats"][3]["stats"]["Fouls committed"])
        except:
            foules_committed_local.append(0)
        try:
            penalties_won_local.append(titus_local[1][i]["stats"][1]["stats"]["Penalties won"])
        except:
            penalties_won_local.append(0)
        try:
            corner_local.append(titus_local[1][i]["stats"][1]["stats"]["Corners"])
        except:
            corner_local.append(0)


    for j in range(0,int(formacion_local[4])):
        id_match_L.append(match_id)
        fecha_L.append(fecha)
        id_team_L.append(team_id_L)
        equipo_L.append(equipo_local)
        home.append("home")
        home_player.append("titular")
        player_id_l.append(titus_local[2][j]["id"])
        nombre_local.append(titus_local[2][j]["name"]["lastName"])
        posicion_local.append(titus_local[2][j]["role"])
        shirt_local.append(titus_local[2][j]["shirt"])
        try:
            minutes_local.append(titus_local[2][j]["minutesPlayed"])
        except:
            minutes_local.append(0)
        try:
            rating_local.append(titus_local[2][j]["stats"][0]["stats"]["FotMob rating"])
        except:
            rating_local.append(0)
        try:
            goals_local.append(titus_local[2][j]["stats"][0]["stats"]["Goals"])
        except:
            goals_local.append(0)
        try:
            assists_local.append(titus_local[2][j]["stats"][0]["stats"]["Assists"])
        except:
            assists_local.append(0)
        try:
            shots_local.append(titus_local[2][j]["stats"][0]["stats"]["Total shots"])
        except:
            shots_local.append(0)
        try:
            accurate_passes_local.append(titus_local[2][j]["stats"][0]["stats"]["Accurate passes"])
        except:
            accurate_passes_local.append(0)
        try:
            chances_created_local.append(titus_local[2][j]["stats"][0]["stats"]["Chances created"])
        except:
            chances_created_local.append(0)
        try:
            xg_local.append(titus_local[2][j]["stats"][0]["stats"]["Expected goals (xG)"])
        except:
            xg_local.append(0)
        try:
            xgot_local.append(titus_local[2][j]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
        except:
            xgot_local.append(0)
        try:
            xa_local.append(titus_local[2][j]["stats"][0]["stats"]['Expected assists (xA)'])
        except:
            xa_local.append(0)
        try:
            blocked_shots_local.append(titus_local[2][j]["stats"][1]["stats"]["Blocked shots"])
        except:
            blocked_shots_local.append(0)
        try:
            touches_local.append(titus_local[2][j]["stats"][1]["stats"]["Touches"])
        except:
            touches_local.append(0)
        try:
            successful_dribbles_local.append(titus_local[2][j]["stats"][1]["stats"]["Successful dribbles"])
        except:
            successful_dribbles_local.append(0)
        try:
            passes_into_final_third_local.append(titus_local[2][j]["stats"][1]["stats"]["Passes into final third"])
        except:
            passes_into_final_third_local.append(0)
        try:
            accurate_crosses_local.append(titus_local[2][j]["stats"][1]["stats"]["Accurate crosses"])
        except:
            accurate_crosses_local.append(0)
        try:
            accurate_long_balls_local.append(titus_local[2][j]["stats"][1]["stats"]["Accurate long balls"])
        except:
            accurate_long_balls_local.append(0)
        try:
            dispossessed_local.append(titus_local[2][j]["stats"][1]["stats"]["Dispossessed"])
        except:
            dispossessed_local.append(0)
        try:
            tackles_won_local.append(titus_local[2][j]["stats"][2]["stats"]["Tackles won"])
        except:
            tackles_won_local.append(0)
        try:
            clearances_local.append(titus_local[2][j]["stats"][2]["stats"]["Clearances"])
        except:
            clearances_local.append(0)
        try:
            headed_clearances_local.append(titus_local[2][j]["stats"][2]["stats"]["Headed clearance"])
        except:
            headed_clearances_local.append(0)
        try:
            interceptions_local.append(titus_local[2][j]["stats"][2]["stats"]["Interceptions"])
        except:
            interceptions_local.append(0)
        try:
            recoveries_local.append(titus_local[2][j]["stats"][2]["stats"]["Recoveries"])
        except:
            recoveries_local.append(0)
        try:
            ground_duels_won_local.append(titus_local[2][j]["stats"][3]["stats"]["Ground duels won"])
        except:
            ground_duels_won_local.append(0)
        try:
            aerial_duels_won_local.append(titus_local[3][z]["stats"][3]["stats"]["Aerial duels won"])
        except:
            aerial_duels_won_local.append(0)
        try:
            was_fouled_local.append(titus_local[2][j]["stats"][3]["stats"]["Was fouled"])
        except:
            was_fouled_local.append(0)
        try:
            foules_committed_local.append(titus_local[2][j]["stats"][3]["stats"]["Fouls committed"])
        except:
            foules_committed_local.append(0)
        try:
            penalties_won_local.append(titus_local[2][j]["stats"][1]["stats"]["Penalties won"])
        except:
            penalties_won_local.append(0)
        try:
            corner_local.append(titus_local[2][j]["stats"][1]["stats"]["Corners"])
        except:
            corner_local.append(0)




    for z in range(0,int(formacion_local[8])):
        id_match_L.append(match_id)
        fecha_L.append(fecha)
        id_team_L.append(team_id_L)
        equipo_L.append(equipo_local)
        home.append("home")
        player_id_l.append(titus_local[3][z]["id"])
        home_player.append("titular")
        nombre_local.append(titus_local[3][z]["name"]["lastName"])
        posicion_local.append(titus_local[3][z]["role"])
        shirt_local.append(titus_local[3][z]["shirt"])
        try:
            minutes_local.append(titus_local[3][z]["minutesPlayed"])
        except:
            minutes_local.append(0)
        try:    
            rating_local.append(titus_local[3][z]["stats"][0]["stats"]["FotMob rating"].value())
        except:
            rating_local.append(0)
        try:
            goals_local.append(titus_local[3][z]["stats"][0]["stats"]["Goals"])
        except:
            goals_local.append(0)
        try:    
            assists_local.append(titus_local[3][z]["stats"][0]["stats"]["Assists"])
        except:
            assists_local.append(0)
        try:
            shots_local.append(titus_local[3][z]["stats"][0]["stats"]["Total shots"])
        except:
            shots_local.append(0)
        try:    
            accurate_passes_local.append(titus_local[3][z]["stats"][0]["stats"]["Accurate passes"])
        except:
            accurate_passes_local.append(0)
        try:
            chances_created_local.append(titus_local[3][z]["stats"][0]["stats"]["Chances created"])
        except:
            chances_created_local.append(0)
        try:
            xg_local.append(titus_local[3][z]["stats"][0]["stats"]["Expected goals (xG)"])
        except:
            xg_local.append(0)
        try:
            xgot_local.append(titus_local[3][z]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
        except:
            xgot_local.append(0)
        try:
            xa_local.append(titus_local[3][z]["stats"][0]["stats"]['Expected assists (xA)'])
        except:
            xa_local.append(0)
        try:
            blocked_shots_local.append(titus_local[3][z]["stats"][1]["stats"]["Blocked shots"])
        except:
            blocked_shots_local.append(0)
        try:
            touches_local.append(titus_local[3][z]["stats"][1]["stats"]["Touches"])
        except:
            touches_local.append(0)
        try:
            successful_dribbles_local.append(titus_local[3][z]["stats"][1]["stats"]["Successful dribbles"])
        except:
            successful_dribbles_local.append(0)
        try:
            passes_into_final_third_local.append(titus_local[3][z]["stats"][1]["stats"]["Passes into final third"])
        except:
            passes_into_final_third_local.append(0)
        try:
            accurate_crosses_local.append(titus_local[3][z]["stats"][1]["stats"]["Accurate crosses"])
        except:
            accurate_crosses_local.append(0)
        try:
            accurate_long_balls_local.append(titus_local[3][z]["stats"][1]["stats"]["Accurate long balls"])
        except:
            accurate_long_balls_local.append(0)
        try:
            dispossessed_local.append(titus_local[3][z]["stats"][1]["stats"]["Dispossessed"])
        except:
            dispossessed_local.append(0)
        try:
            tackles_won_local.append(titus_local[3][z]["stats"][2]["stats"]["Tackles won"])
        except:
            tackles_won_local.append(0)
        try:
            clearances_local.append(titus_local[3][z]["stats"][2]["stats"]["Clearances"])
        except:
            clearances_local.append(0)
        try:
            headed_clearances_local.append(titus_local[3][z]["stats"][2]["stats"]["Headed clearance"])
        except:
            headed_clearances_local.append(0)
        try:
            interceptions_local.append(titus_local[3][z]["stats"][2]["stats"]["Interceptions"])
        except:
            interceptions_local.append(0)
        try:
            recoveries_local.append(titus_local[3][z]["stats"][2]["stats"]["Recoveries"])
        except:
            recoveries_local.append(0)
        try:
            ground_duels_won_local.append(titus_local[3][z]["stats"][3]["stats"]["Ground duels won"])
        except:
            ground_duels_won_local.append(0)
        try:
            aerial_duels_won_local.append(titus_local[3][z]["stats"][3]["stats"]["Aerial duels won"])
        except:
            aerial_duels_won_local.append(0)
        try:
            was_fouled_local.append(titus_local[3][z]["stats"][3]["stats"]["Was fouled"])
        except:
            was_fouled_local.append(0)
        try:
            foules_committed_local.append(titus_local[3][z]["stats"][3]["stats"]["Fouls committed"])
        except:
            foules_committed_local.append(0)
        try:
            penalties_won_local.append(titus_local[3][z]["stats"][1]["stats"]["Penalties won"])
        except:
            penalties_won_local.append(0)
        try:
            corner_local.append(titus_local[3][z]["stats"][1]["stats"]["Corners"])
        except:
            corner_local.append(0)
            
            
            
    if len(formacion_local) >9:
        for l in range(0,int(formacion_local[12])):
            id_match_L.append(match_id)
            fecha_L.append(fecha)
            id_team_L.append(team_id_L)
            equipo_L.append(equipo_local)
            home.append("home")
            player_id_l.append(titus_local[4][l]["id"])
            home_player.append("titular")
            nombre_local.append(titus_local[4][l]["name"]["lastName"])
            posicion_local.append(titus_local[4][l]["role"])
            shirt_local.append(titus_local[4][l]["shirt"])
            try:
                minutes_local.append(titus_local[4][l]["minutesPlayed"])
            except:
                minutes_local.append(0)
            try:
                rating_local.append(titus_local[4][l]["stats"][0]["stats"]["FotMob rating"])
            except:
                rating_local.append(0)
            try:
                goals_local.append(titus_local[4][l]["stats"][0]["stats"]["Goals"])
            except:
                goals_local.append(0)
            try:
                assists_local.append(titus_local[4][l]["stats"][0]["stats"]["Assists"])
            except:
                assists_local.append(0)
            try:
                shots_local.append(titus_local[4][l]["stats"][0]["stats"]["Total shots"])
            except:
                shots_local.append(0)
            try:
                accurate_passes_local.append(titus_local[4][l]["stats"][0]["stats"]["Accurate passes"])
            except:
                accurate_passes_local.append(0)
            try:
                chances_created_local.append(titus_local[4][l]["stats"][0]["stats"]["Chances created"])
            except:
                chances_created_local.append(0)
            try:
                xg_local.append(titus_local[4][l]["stats"][0]["stats"]["Expected goals (xG)"])
            except:
                xg_local.append(0)
            try:
                xgot_local.append(titus_local[4][l]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
            except:
                xgot_local.append(0)
            try:
                xa_local.append(titus_local[4][l]["stats"][0]["stats"]['Expected assists (xA)'])
            except:
                xa_local.append(0)
            try:
                blocked_shots_local.append(titus_local[4][l]["stats"][1]["stats"]["Blocked shots"])
            except:
                blocked_shots_local.append(0)
            try:
                touches_local.append(titus_local[4][l]["stats"][1]["stats"]["Touches"])
            except:
                touches_local.append(0)
            try:
                successful_dribbles_local.append(titus_local[4][l]["stats"][1]["stats"]["Successful dribbles"])
            except:
                successful_dribbles_local.append(0)
            try:
                passes_into_final_third_local.append(titus_local[4][l]["stats"][1]["stats"]["Passes into final third"])
            except:
                passes_into_final_third_local.append(0)
            try:
                accurate_crosses_local.append(titus_local[4][l]["stats"][1]["stats"]["Accurate crosses"])
            except:
                accurate_crosses_local.append(0)
            try:
                accurate_long_balls_local.append(titus_local[4][l]["stats"][1]["stats"]["Accurate long balls"])
            except:
                accurate_long_balls_local.append(0)
            try:
                dispossessed_local.append(titus_local[4][l]["stats"][1]["stats"]["Dispossessed"])
            except:
                dispossessed_local.append(0)
            try:
                tackles_won_local.append(titus_local[4][l]["stats"][2]["stats"]["Tackles won"])
            except:
                tackles_won_local.append(0)
            try:
                clearances_local.append(titus_local[4][l]["stats"][2]["stats"]["Clearances"])
            except:
                clearances_local.append(0)
            try:
                headed_clearances_local.append(titus_local[4][l]["stats"][2]["stats"]["Headed clearance"])
            except:
                headed_clearances_local.append(0)
            try:
                interceptions_local.append(titus_local[4][l]["stats"][2]["stats"]["Interceptions"])
            except:
                interceptions_local.append(0)
            try:
                recoveries_local.append(titus_local[4][l]["stats"][2]["stats"]["Recoveries"])
            except:
                recoveries_local.append(0)
            try:
                ground_duels_won_local.append(titus_local[4][l]["stats"][3]["stats"]["Ground duels won"])
            except:
                ground_duels_won_local.append(0)
            try:
                aerial_duels_won_local.append(titus_local[4][l]["stats"][3]["stats"]["Aerial duels won"])
            except:
                aerial_duels_won_local.append(0)
            try:
                was_fouled_local.append(titus_local[4][l]["stats"][3]["stats"]["Was fouled"])
            except:
                was_fouled_local.append(0)
            try:
                foules_committed_local.append(titus_local[4][l]["stats"][3]["stats"]["Fouls committed"])
            except:
                foules_committed_local.append(0)
            try:
                penalties_won_local.append(titus_local[4][l]["stats"][1]["stats"]["Penalties won"])
            except:
                penalties_won_local.append(0)
            try:
                corner_local.append(titus_local[4][l]["stats"][1]["stats"]["Corners"])
            except:
                corner_local.append(0)

    




    #nombre_local.append(titus_local[0][0]["name"]["lastName"])
    #shirt_local.append(titus_local[0][0]["shirt"])
    #minutes_local.append(titus_local[0][0]["minutesPlayed"])
    
    
    if len(formacion_visitante)==9:
        
        for i in range(0,int(formacion_visitante[8])):
            id_match_V.append(match_id)
            fecha_V.append(fecha)
            id_team_V.append(team_id_V)
            equipo_V.append(equipo_visitante)
            away.append("away")
            away_player.append("titular")
            player_id_v.append(titus_visitante[0][i]["id"])
            nombre_visitante.append(titus_visitante[0][i]["name"]["lastName"])
            posicion_visitante.append(titus_visitante[0][0]["role"])
            shirt_visitante.append(titus_visitante[0][i]["shirt"])
            try:
                minutes_visitante.append(titus_visitante[0][i]["minutesPlayed"])
            except:
                minutes_visitante.append(0)
            try:
                rating_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["FotMob rating"])
            except:
                rating_visitante.append(0)
            try:
                goals_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Goals"])
            except:
                goals_visitante.append(0)
            try:
                assists_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Assists"])
            except:
                assists_visitante.append(0)
            try:
                shots_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Total shots"])
            except:
                shots_visitante.append(0)
            try:
                accurate_passes_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Accurate passes"])
            except:
                accurate_passes_visitante.append(0)
            try:    
                chances_created_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Chances created"])
            except:
                chances_created_visitante.append(0)
            try:
                xg_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Expected goals (xG)"])
            except:
                xg_visitante.append(0)
            try:
                xgot_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
            except:
                xgot_visitante.append(0)
            try:
                xa_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]['Expected assists (xA)'])
            except:
                xa_visitante.append(0)
            try:
                blocked_shots_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Blocked shots"])
            except:
                blocked_shots_visitante.append(0)
            try:
                touches_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Touches"])
            except:
                touches_visitante.append(0)
            try:
                successful_dribbles_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Successful dribbles"])
            except:
                successful_dribbles_visitante.append(0)
            try:
                passes_into_final_third_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Passes into final third"])
            except:
                passes_into_final_third_visitante.append(0)
            try:
                accurate_crosses_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Accurate crosses"])
            except:
                accurate_crosses_visitante.append(0)
            try:
                accurate_long_balls_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Accurate long balls"])
            except:
                accurate_long_balls_visitante.append(0)
            try:
                dispossessed_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Dispossessed"])
            except:
                dispossessed_visitante.append(0)
            try:
                tackles_won_visitante.append(titus_visitante[0][i]["stats"][2]["stats"]["Tackles won"])
            except:
                tackles_won_visitante.append(0)
            try:
                clearances_visitante.append(titus_visitante[0][i]["stats"][2]["stats"]["Clearances"])
            except:
                clearances_visitante.append(0)
            try:
                headed_clearances_visitante.append(titus_visitante[0][i]["stats"][2]["stats"]["Headed clearance"])
            except:
                headed_clearances_visitante.append(0)
            try:
                interceptions_visitante.append(titus_visitante[0][i]["stats"][2]["stats"]["Interceptions"])
            except:
                interceptions_visitante.append(0)
            try:
                recoveries_visitante.append(titus_visitante[0][i]["stats"][2]["stats"]["Recoveries"])
            except:
                recoveries_visitante.append(0)
            try:
                ground_duels_won_visitante.append(titus_visitante[0][i]["stats"][3]["stats"]["Ground duels won"])
            except:
                ground_duels_won_visitante.append(0)
            try:
                aerial_duels_won_visitante.append(titus_visitante[0][z]["stats"][3]["stats"]["Aerial duels won"])
            except:
                aerial_duels_won_visitante.append(0)
            try:
                was_fouled_visitante.append(titus_visitante[0][i]["stats"][3]["stats"]["Was fouled"])
            except:
                was_fouled_visitante.append(0)
            try:
                foules_committed_visitante.append(titus_visitante[0][i]["stats"][3]["stats"]["Fouls committed"])
            except:
                foules_committed_visitante.append(0)
            try:
                penalties_won_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Penalties won"])
            except:
                penalties_won_visitante.append(0)
            try:
                corner_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Corners"])
            except:
                corner_visitante.append(0)


        for j in range(0,int(formacion_visitante[4])):
            id_match_V.append(match_id)
            fecha_V.append(fecha)
            id_team_V.append(team_id_V)
            equipo_V.append(equipo_visitante)
            away.append("away")
            player_id_v.append(titus_visitante[1][j]["id"])
            away_player.append("titular")
            nombre_visitante.append(titus_visitante[1][j]["name"]["lastName"])
            posicion_visitante.append(titus_visitante[1][j]["role"])
            shirt_visitante.append(titus_visitante[1][j]["shirt"])
            try:
                minutes_visitante.append(titus_visitante[1][j]["minutesPlayed"])
            except:
                minutes_visitante.append(0)
            try:
                rating_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["FotMob rating"])
            except:
                rating_visitante.append(0)
            try:
                goals_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Goals"])
            except:
                goals_visitante.append(0)
            try:
                assists_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Assists"])
            except:
                assists_visitante.append(0)
            try:
                shots_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Total shots"])
            except:
                shots_visitante.append(0)
            try:
                accurate_passes_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Accurate passes"])
            except:
                accurate_passes_visitante.append(0)
            try:
                chances_created_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Chances created"])
            except:
                chances_created_visitante.append(0)
            try:
                xg_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Expected goals (xG)"])
            except:
                xg_visitante.append(0)
            try:
                xgot_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
            except:
                xgot_visitante.append(0)
            try:
                xa_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]['Expected assists (xA)'])
            except:
                xa_visitante.append(0)
            try:
                blocked_shots_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Blocked shots"])
            except:
                blocked_shots_visitante.append(0)
            try:
                touches_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Touches"])
            except:
                touches_visitante.append(0)
            try:
                successful_dribbles_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Successful dribbles"])
            except:
                successful_dribbles_visitante.append(0)
            try:
                passes_into_final_third_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Passes into final third"])
            except:
                passes_into_final_third_visitante.append(0)
            try:
                accurate_crosses_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Accurate crosses"])
            except:
                accurate_crosses_visitante.append(0)
            try:
                accurate_long_balls_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Accurate long balls"])
            except:
                accurate_long_balls_visitante.append(0)
            try:
                dispossessed_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Dispossessed"])
            except:
                dispossessed_visitante.append(0)
            try:
                tackles_won_visitante.append(titus_visitante[1][j]["stats"][2]["stats"]["Tackles won"])
            except:
                tackles_won_visitante.append(0)
            try:
                clearances_visitante.append(titus_visitante[1][j]["stats"][2]["stats"]["Clearances"])
            except:
                clearances_visitante.append(0)
            try:
                headed_clearances_visitante.append(titus_visitante[1][j]["stats"][2]["stats"]["Headed clearance"])
            except:
                headed_clearances_visitante.append(0)
            try:
                interceptions_visitante.append(titus_visitante[1][j]["stats"][2]["stats"]["Interceptions"])
            except:
                interceptions_visitante.append(0)
            try:
                recoveries_visitante.append(titus_visitante[1][j]["stats"][2]["stats"]["Recoveries"])
            except:
                recoveries_visitante.append(0)
            try:
                ground_duels_won_visitante.append(titus_visitante[1][j]["stats"][3]["stats"]["Ground duels won"])
            except:
                ground_duels_won_visitante.append(0)
            try:
                aerial_duels_won_visitante.append(titus_visitante[1][j]["stats"][3]["stats"]["Aerial duels won"])
            except:
                aerial_duels_won_visitante.append(0)
            try:
                was_fouled_visitante.append(titus_visitante[1][j]["stats"][3]["stats"]["Was fouled"])
            except:
                was_fouled_visitante.append(0)
            try:
                foules_committed_visitante.append(titus_visitante[1][j]["stats"][3]["stats"]["Fouls committed"])
            except:
                foules_committed_visitante.append(0)
            try:
                penalties_won_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Penalties won"])
            except:
                penalties_won_visitante.append(0)
            try:
                corner_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Corners"])
            except:
                corner_visitante.append(0)




        for z in range(0,int(formacion_visitante[0])):
            id_match_V.append(match_id)
            fecha_V.append(fecha)
            id_team_V.append(team_id_V)
            equipo_V.append(equipo_visitante)
            away.append("away")
            player_id_v.append(titus_visitante[2][z]["id"])
            away_player.append("titular")
            nombre_visitante.append(titus_visitante[2][z]["name"]["lastName"])
            posicion_visitante.append(titus_visitante[2][z]["role"])
            shirt_visitante.append(titus_visitante[2][z]["shirt"])
            try:
                minutes_visitante.append(titus_visitante[2][z]["minutesPlayed"])
            except:
                minutes_visitante.append(0)
            try:
                rating_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["FotMob rating"])
            except:
                rating_visitante.append(0)
            try:
                goals_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Goals"])
            except:
                goals_visitante.append(0)
            try:
                assists_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Assists"])
            except:
                assists_visitante.append(0)
            try:
                shots_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Total shots"])
            except:
                shots_visitante.append(0)
            try:
                accurate_passes_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Accurate passes"])
            except:
                accurate_passes_visitante.append(0)
            try:
                chances_created_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Chances created"])
            except:
                chances_created_visitante.append(0)
            try:
                xg_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Expected goals (xG)"])
            except:
                xg_visitante.append(0)
            try:
                xgot_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
            except:
                xgot_visitante.append(0)
            try:
                xa_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]['Expected assists (xA)'])
            except:
                xa_visitante.append(0)
            try:
                blocked_shots_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Blocked shots"])
            except:
                blocked_shots_visitante.append(0)
            try:
                touches_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Touches"])
            except:
                touches_visitante.append(0)
            try:
                successful_dribbles_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Successful dribbles"])
            except:
                successful_dribbles_visitante.append(0)
            try:
                passes_into_final_third_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Passes into final third"])
            except:
                passes_into_final_third_visitante.append(0)
            try:
                accurate_crosses_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Accurate crosses"])
            except:
                accurate_crosses_visitante.append(0)
            try:
                accurate_long_balls_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Accurate long balls"])
            except:
                accurate_long_balls_visitante.append(0)
            try:
                dispossessed_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Dispossessed"])
            except:
                dispossessed_visitante.append(0)
            try:
                tackles_won_visitante.append(titus_visitante[2][z]["stats"][2]["stats"]["Tackles won"])
            except:
                tackles_won_visitante.append(0)
            try:
                clearances_visitante.append(titus_visitante[2][z]["stats"][2]["stats"]["Clearances"])
            except:
                clearances_visitante.append(0)
            try:
                headed_clearances_visitante.append(titus_visitante[2][z]["stats"][2]["stats"]["Headed clearance"])
            except:
                headed_clearances_visitante.append(0)
            try:
                interceptions_visitante.append(titus_visitante[2][z]["stats"][2]["stats"]["Interceptions"])
            except:
                interceptions_visitante.append(0)
            try:
                recoveries_visitante.append(titus_visitante[2][z]["stats"][2]["stats"]["Recoveries"])
            except:
                recoveries_visitante.append(0)
            try:
                ground_duels_won_visitante.append(titus_visitante[2][z]["stats"][3]["stats"]["Ground duels won"])
            except:
                ground_duels_won_visitante.append(0)
            try:
                aerial_duels_won_visitante.append(titus_visitante[2][z]["stats"][3]["stats"]["Aerial duels won"])
            except:
                aerial_duels_won_visitante.append(0)
            try:
                was_fouled_visitante.append(titus_visitante[2][z]["stats"][3]["stats"]["Was fouled"])
            except:
                was_fouled_visitante.append(0)
            try:
                foules_committed_visitante.append(titus_visitante[2][z]["stats"][3]["stats"]["Fouls committed"])
            except:
                foules_committed_visitante.append(0)
            try:
                penalties_won_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Penalties won"])
            except:
                penalties_won_visitante.append(0)
            try:
                corner_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Corners"])
            except:
                corner_visitante.append(0)
    else:
        for l in range(0,int(formacion_visitante[0])):
            id_match_V.append(match_id)
            fecha_V.append(fecha)
            id_team_V.append(team_id_V)
            equipo_V.append(equipo_visitante)
            away.append("away")
            try:
                player_id_v.append(titus_visitante[3][l]["id"])
            except:
                player_id_v.append("")
            away_player.append("titular")
            try:
                nombre_visitante.append(titus_visitante[3][l]["name"]["lastName"])
            except:
                nombre_visitante.append("")
            try:
                posicion_visitante.append(titus_visitante[3][l]["role"])
            except:
                posicion_visitante.append("")
            try:
                shirt_visitante.append(titus_visitante[3][l]["shirt"])
            except:
                shirt_visitante.append(0)
            try:
                minutes_visitante.append(titus_visitante[3][l]["minutesPlayed"])
            except:
                minutes_visitante.append(0)
            try:
                rating_visitante.append(titus_visitante[3][l]["stats"][0]["stats"]["FotMob rating"])
            except:
                rating_visitante.append(0)
            try:
                goals_visitante.append(titus_visitante[3][l]["stats"][0]["stats"]["Goals"])
            except:
                goals_visitante.append(0)
            try:
                assists_visitante.append(titus_visitante[3][l]["stats"][0]["stats"]["Assists"])
            except:
                assists_visitante.append(0)
            try:
                shots_visitante.append(titus_visitante[3][l]["stats"][0]["stats"]["Total shots"])
            except:
                shots_visitante.append(0)
            try:
                accurate_passes_visitante.append(titus_visitante[3][l]["stats"][0]["stats"]["Accurate passes"])
            except:
                accurate_passes_visitante.append(0)
            try:
                chances_created_visitante.append(titus_visitante[3][l]["stats"][0]["stats"]["Chances created"])
            except:
                chances_created_visitante.append(0)
            try:
                xg_visitante.append(titus_visitante[3][l]["stats"][0]["stats"]["Expected goals (xG)"])
            except:
                xg_visitante.append(0)
            try:
                xgot_visitante.append(titus_visitante[3][l]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
            except:
                xgot_visitante.append(0)
            try:
                xa_visitante.append(titus_visitante[3][l]["stats"][0]["stats"]['Expected assists (xA)'])
            except:
                xa_visitante.append(0)
            try:
                blocked_shots_visitante.append(titus_visitante[3][l]["stats"][1]["stats"]["Blocked shots"])
            except:
                blocked_shots_visitante.append(0)
            try:
                touches_visitante.append(titus_visitante[3][l]["stats"][1]["stats"]["Touches"])
            except:
                touches_visitante.append(0)
            try:
                successful_dribbles_visitante.append(titus_visitante[3][l]["stats"][1]["stats"]["Successful dribbles"])
            except:
                successful_dribbles_visitante.append(0)
            try:
                passes_into_final_third_visitante.append(titus_visitante[3][l]["stats"][1]["stats"]["Passes into final third"])
            except:
                passes_into_final_third_visitante.append(0)
            try:
                accurate_crosses_visitante.append(titus_visitante[3][l]["stats"][1]["stats"]["Accurate crosses"])
            except:
                accurate_crosses_visitante.append(0)
            try:
                accurate_long_balls_visitante.append(titus_visitante[3][l]["stats"][1]["stats"]["Accurate long balls"])
            except:
                accurate_long_balls_visitante.append(0)
            try:
                dispossessed_visitante.append(titus_visitante[3][l]["stats"][1]["stats"]["Dispossessed"])
            except:
                dispossessed_visitante.append(0)
            try:
                tackles_won_visitante.append(titus_visitante[3][l]["stats"][2]["stats"]["Tackles won"])
            except:
                tackles_won_visitante.append(0)
            try:
                clearances_visitante.append(titus_visitante[3][l]["stats"][2]["stats"]["Clearances"])
            except:
                clearances_visitante.append(0)
            try:
                headed_clearances_visitante.append(titus_visitante[3][l]["stats"][2]["stats"]["Headed clearance"])
            except:
                headed_clearances_visitante.append(0)
            try:
                interceptions_visitante.append(titus_visitante[3][l]["stats"][2]["stats"]["Interceptions"])
            except:
                interceptions_visitante.append(0)
            try:
                recoveries_visitante.append(titus_visitante[3][l]["stats"][2]["stats"]["Recoveries"])
            except:
                recoveries_visitante.append(0)
            try:
                ground_duels_won_visitante.append(titus_visitante[3][l]["stats"][3]["stats"]["Ground duels won"])
            except:
                ground_duels_won_visitante.append(0)
            try:
                aerial_duels_won_visitante.append(titus_visitante[3][l]["stats"][3]["stats"]["Aerial duels won"])
            except:
                aerial_duels_won_visitante.append(0)
            try:
                was_fouled_visitante.append(titus_visitante[3][l]["stats"][3]["stats"]["Was fouled"])
            except:
                was_fouled_visitante.append(0)
            try:
                foules_committed_visitante.append(titus_visitante[3][l]["stats"][3]["stats"]["Fouls committed"])
            except:
                foules_committed_visitante.append(0)
            try:
                penalties_won_visitante.append(titus_visitante[3][l]["stats"][1]["stats"]["Penalties won"])
            except:
                penalties_won_visitante.append(0)
            try:
                corner_visitante.append(titus_visitante[3][l]["stats"][1]["stats"]["Corners"])
            except:
                corner_visitante.append(0)
        
        for i in range(0,int(formacion_visitante[12])):
            id_match_V.append(match_id)
            fecha_V.append(fecha)
            id_team_V.append(team_id_V)
            equipo_V.append(equipo_visitante)
            away.append("away")
            away_player.append("titular")
            nombre_visitante.append(titus_visitante[0][i]["name"]["lastName"])
            posicion_visitante.append(titus_visitante[0][0]["role"])
            shirt_visitante.append(titus_visitante[0][i]["shirt"])
            player_id_v.append(titus_visitante[0][i]["id"])
            try:
                minutes_visitante.append(titus_visitante[0][i]["minutesPlayed"])
            except:
                minutes_visitante.append(0)
            try:
                rating_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["FotMob rating"])
            except:
                rating_visitante.append(0)
            try:
                goals_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Goals"])
            except:
                goals_visitante.append(0)
            try:
                assists_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Assists"])
            except:
                assists_visitante.append(0)
            try:
                shots_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Total shots"])
            except:
                shots_visitante.append(0)
            try:
                accurate_passes_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Accurate passes"])
            except:
                accurate_passes_visitante.append(0)
            try:    
                chances_created_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Chances created"])
            except:
                chances_created_visitante.append(0)
            try:
                xg_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Expected goals (xG)"])
            except:
                xg_visitante.append(0)
            try:
                xgot_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
            except:
                xgot_visitante.append(0)
            try:
                xa_visitante.append(titus_visitante[0][i]["stats"][0]["stats"]['Expected assists (xA)'])
            except:
                xa_visitante.append(0)
            try:
                blocked_shots_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Blocked shots"])
            except:
                blocked_shots_visitante.append(0)
            try:
                touches_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Touches"])
            except:
                touches_visitante.append(0)
            try:
                successful_dribbles_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Successful dribbles"])
            except:
                successful_dribbles_visitante.append(0)
            try:
                passes_into_final_third_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Passes into final third"])
            except:
                passes_into_final_third_visitante.append(0)
            try:
                accurate_crosses_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Accurate crosses"])
            except:
                accurate_crosses_visitante.append(0)
            try:
                accurate_long_balls_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Accurate long balls"])
            except:
                accurate_long_balls_visitante.append(0)
            try:
                dispossessed_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Dispossessed"])
            except:
                dispossessed_visitante.append(0)
            try:
                tackles_won_visitante.append(titus_visitante[0][i]["stats"][2]["stats"]["Tackles won"])
            except:
                tackles_won_visitante.append(0)
            try:
                clearances_visitante.append(titus_visitante[0][i]["stats"][2]["stats"]["Clearances"])
            except:
                clearances_visitante.append(0)
            try:
                headed_clearances_visitante.append(titus_visitante[0][i]["stats"][2]["stats"]["Headed clearance"])
            except:
                headed_clearances_visitante.append(0)
            try:
                interceptions_visitante.append(titus_visitante[0][i]["stats"][2]["stats"]["Interceptions"])
            except:
                interceptions_visitante.append(0)
            try:
                recoveries_visitante.append(titus_visitante[0][i]["stats"][2]["stats"]["Recoveries"])
            except:
                recoveries_visitante.append(0)
            try:
                ground_duels_won_visitante.append(titus_visitante[0][i]["stats"][3]["stats"]["Ground duels won"])
            except:
                ground_duels_won_visitante.append(0)
            try:
                aerial_duels_won_visitante.append(titus_visitante[0][z]["stats"][3]["stats"]["Aerial duels won"])
            except:
                aerial_duels_won_visitante.append(0)
            try:
                was_fouled_visitante.append(titus_visitante[0][i]["stats"][3]["stats"]["Was fouled"])
            except:
                was_fouled_visitante.append(0)
            try:
                foules_committed_visitante.append(titus_visitante[0][i]["stats"][3]["stats"]["Fouls committed"])
            except:
                foules_committed_visitante.append(0)
            try:
                penalties_won_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Penalties won"])
            except:
                penalties_won_visitante.append(0)
            try:
                corner_visitante.append(titus_visitante[0][i]["stats"][1]["stats"]["Corners"])
            except:
                corner_visitante.append(0)


        for j in range(0,int(formacion_visitante[8])):
            id_match_V.append(match_id)
            fecha_V.append(fecha)
            id_team_V.append(team_id_V)
            equipo_V.append(equipo_visitante)
            away.append("away")
            away_player.append("titular")
            try:
                player_id_v.append(titus_visitante[1][j]["id"])
            except:
                player_id_v.append("")
            try:
                nombre_visitante.append(titus_visitante[1][j]["name"]["lastName"])
            except:
                nombre_visitante.append("")
            try:
                posicion_visitante.append(titus_visitante[1][j]["role"])
            except:
                posicion_visitante.append("")
            try:
                shirt_visitante.append(titus_visitante[1][j]["shirt"])
            except:
                shirt_visitante.append(0)
            try:
                minutes_visitante.append(titus_visitante[1][j]["minutesPlayed"])
            except:
                minutes_visitante.append(0)
            try:
                rating_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["FotMob rating"])
            except:
                rating_visitante.append(0)
            try:
                goals_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Goals"])
            except:
                goals_visitante.append(0)
            try:
                assists_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Assists"])
            except:
                assists_visitante.append(0)
            try:
                shots_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Total shots"])
            except:
                shots_visitante.append(0)
            try:
                accurate_passes_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Accurate passes"])
            except:
                accurate_passes_visitante.append(0)
            try:    
                chances_created_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Chances created"])
            except:
                chances_created_visitante.append(0)
            try:
                xg_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Expected goals (xG)"])
            except:
                xg_visitante.append(0)
            try:
                xgot_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
            except:
                xgot_visitante.append(0)
            try:
                xa_visitante.append(titus_visitante[1][j]["stats"][0]["stats"]['Expected assists (xA)'])
            except:
                xa_visitante.append(0)
            try:
                blocked_shots_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Blocked shots"])
            except:
                blocked_shots_visitante.append(0)
            try:
                touches_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Touches"])
            except:
                touches_visitante.append(0)
            try:
                successful_dribbles_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Successful dribbles"])
            except:
                successful_dribbles_visitante.append(0)
            try:
                passes_into_final_third_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Passes into final third"])
            except:
                passes_into_final_third_visitante.append(0)
            try:
                accurate_crosses_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Accurate crosses"])
            except:
                accurate_crosses_visitante.append(0)
            try:
                accurate_long_balls_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Accurate long balls"])
            except:
                accurate_long_balls_visitante.append(0)
            try:
                dispossessed_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Dispossessed"])
            except:
                dispossessed_visitante.append(0)
            try:
                tackles_won_visitante.append(titus_visitante[1][j]["stats"][2]["stats"]["Tackles won"])
            except:
                tackles_won_visitante.append(0)
            try:
                clearances_visitante.append(titus_visitante[1][j]["stats"][2]["stats"]["Clearances"])
            except:
                clearances_visitante.append(0)
            try:
                headed_clearances_visitante.append(titus_visitante[1][j]["stats"][2]["stats"]["Headed clearance"])
            except:
                headed_clearances_visitante.append(0)
            try:
                interceptions_visitante.append(titus_visitante[1][j]["stats"][2]["stats"]["Interceptions"])
            except:
                interceptions_visitante.append(0)
            try:
                recoveries_visitante.append(titus_visitante[1][j]["stats"][2]["stats"]["Recoveries"])
            except:
                recoveries_visitante.append(0)
            try:
                ground_duels_won_visitante.append(titus_visitante[1][j]["stats"][3]["stats"]["Ground duels won"])
            except:
                ground_duels_won_visitante.append(0)
            try:
                aerial_duels_won_visitante.append(titus_visitante[1][j]["stats"][3]["stats"]["Aerial duels won"])
            except:
                aerial_duels_won_visitante.append(0)
            try:
                was_fouled_visitante.append(titus_visitante[1][j]["stats"][3]["stats"]["Was fouled"])
            except:
                was_fouled_visitante.append(0)
            try:
                foules_committed_visitante.append(titus_visitante[1][j]["stats"][3]["stats"]["Fouls committed"])
            except:
                foules_committed_visitante.append(0)
            try:
                penalties_won_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Penalties won"])
            except:
                penalties_won_visitante.append(0)
            try:
                corner_visitante.append(titus_visitante[1][j]["stats"][1]["stats"]["Corners"])
            except:
                corner_visitante.append(0)




        for z in range(0,int(formacion_visitante[4])):
            id_match_V.append(match_id)
            fecha_V.append(fecha)
            id_team_V.append(team_id_V)
            equipo_V.append(equipo_visitante)
            away.append("away")
            away_player.append("titular")
            nombre_visitante.append(titus_visitante[2][z]["name"]["lastName"])
            posicion_visitante.append(titus_visitante[2][z]["role"])
            shirt_visitante.append(titus_visitante[2][z]["shirt"])
            player_id_v.append(titus_visitante[2][z]["id"])
            try:
                minutes_visitante.append(titus_visitante[2][z]["minutesPlayed"])
            except:
                minutes_visitante.append(0)
            try:
                rating_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["FotMob rating"])
            except:
                rating_visitante.append(0)
            try:
                goals_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Goals"])
            except:
                goals_visitante.append(0)
            try:
                assists_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Assists"])
            except:
                assists_visitante.append(0)
            try:
                shots_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Total shots"])
            except:
                shots_visitante.append(0)
            try:
                accurate_passes_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Accurate passes"])
            except:
                accurate_passes_visitante.append(0)
            try:
                chances_created_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Chances created"])
            except:
                chances_created_visitante.append(0)
            try:
                xg_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Expected goals (xG)"])
            except:
                xg_visitante.append(0)
            try:
                xgot_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
            except:
                xgot_visitante.append(0)
            try:
                xa_visitante.append(titus_visitante[2][z]["stats"][0]["stats"]['Expected assists (xA)'])
            except:
                xa_visitante.append(0)
            try:
                blocked_shots_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Blocked shots"])
            except:
                blocked_shots_visitante.append(0)
            try:
                touches_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Touches"])
            except:
                touches_visitante.append(0)
            try:
                successful_dribbles_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Successful dribbles"])
            except:
                successful_dribbles_visitante.append(0)
            try:
                passes_into_final_third_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Passes into final third"])
            except:
                passes_into_final_third_visitante.append(0)
            try:
                accurate_crosses_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Accurate crosses"])
            except:
                accurate_crosses_visitante.append(0)
            try:
                accurate_long_balls_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Accurate long balls"])
            except:
                accurate_long_balls_visitante.append(0)
            try:
                dispossessed_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Dispossessed"])
            except:
                dispossessed_visitante.append(0)
            try:
                tackles_won_visitante.append(titus_visitante[2][z]["stats"][2]["stats"]["Tackles won"])
            except:
                tackles_won_visitante.append(0)
            try:
                clearances_visitante.append(titus_visitante[2][z]["stats"][2]["stats"]["Clearances"])
            except:
                clearances_visitante.append(0)
            try:
                headed_clearances_visitante.append(titus_visitante[2][z]["stats"][2]["stats"]["Headed clearance"])
            except:
                headed_clearances_visitante.append(0)
            try:
                interceptions_visitante.append(titus_visitante[2][z]["stats"][2]["stats"]["Interceptions"])
            except:
                interceptions_visitante.append(0)
            try:
                recoveries_visitante.append(titus_visitante[2][z]["stats"][2]["stats"]["Recoveries"])
            except:
                recoveries_visitante.append(0)
            try:
                ground_duels_won_visitante.append(titus_visitante[2][z]["stats"][3]["stats"]["Ground duels won"])
            except:
                ground_duels_won_visitante.append(0)
            try:
                aerial_duels_won_visitante.append(titus_visitante[2][z]["stats"][3]["stats"]["Aerial duels won"])
            except:
                aerial_duels_won_visitante.append(0)
            try:
                was_fouled_visitante.append(titus_visitante[2][z]["stats"][3]["stats"]["Was fouled"])
            except:
                was_fouled_visitante.append(0)
            try:
                foules_committed_visitante.append(titus_visitante[2][z]["stats"][3]["stats"]["Fouls committed"])
            except:
                foules_committed_visitante.append(0)
            try:
                penalties_won_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Penalties won"])
            except:
                penalties_won_visitante.append(0)
            try:
                corner_visitante.append(titus_visitante[2][z]["stats"][1]["stats"]["Corners"])
            except:
                corner_visitante.append(0)
                
        
    for i in range(0,5):
        id_match_L.append(match_id)
        fecha_L.append(fecha)
        id_team_L.append(team_id_L)
        equipo_L.append(equipo_local)
        home.append("home")
        home_player.append("suplente")
        nombre_local.append(subs_local[i]["name"]["lastName"])
        try:
            player_id_v.append(subs_local[i]["id"])
        except:
            player_id_v.append(0)
        try:
            posicion_local.append(subs_local[i]["role"])
        except:
            posicion_local.append(0)
        try:
            shirt_local.append(subs_local[i]["shirt"])
        except:
            shirt_local.append(0)
        try:
            minutes_local.append(subs_local[i]["minutesPlayed"])
        except:
            minutes_local.append(0)
        try:
            rating_local.append(subs_local[i]["stats"][0]["stats"]["FotMob rating"])
        except:
            rating_local.append(0)
        try:
            goals_local.append(subs_local[i]["stats"][0]["stats"]["Goals"])
        except:
            goals_local.append(0)
        try:
            assists_local.append(subs_local[i]["stats"][0]["stats"]["Assists"])
        except:
             assists_local.append(0)
        try:
            shots_local.append(subs_local[i]["stats"][0]["stats"]["Total shots"])
        except:
            shots_local.append(0)
        try:
            accurate_passes_local.append(subs_local[i]["stats"][0]["stats"]["Accurate passes"])
        except:
            accurate_passes_local.append(0)
        try:
            chances_created_local.append(subs_local[i]["stats"][0]["stats"]["Chances created"])
        except:
            chances_created_local.append(0)
        try:
            xg_local.append(subs_local[i]["stats"][0]["stats"]["Expected goals (xG)"])
        except:
            xg_local.append(0)
        try:
            xgot_local.append(subs_local[i]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
        except:
            xgot_local.append(0)
        try:
            xa_local.append(subs_local[i]["stats"][0]["stats"]['Expected assists (xA)'])
        except:
            xa_local.append(0)
        try:
            blocked_shots_local.append(subs_local[i]["stats"][1]["stats"]["Blocked shots"])
        except:
            blocked_shots_local.append(0)
        try:
            touches_local.append(subs_local[i]["stats"][1]["stats"]["Touches"])
        except:
            touches_local.append(0)
        try:
            successful_dribbles_local.append(subs_local[i]["stats"][1]["stats"]["Successful dribbles"])
        except:
            successful_dribbles_local.append(0)
        try:
            passes_into_final_third_local.append(subs_local[i]["stats"][1]["stats"]["Passes into final third"])
        except:
            passes_into_final_third_local.append(0)
        try:
            accurate_crosses_local.append(subs_local[i]["stats"][1]["stats"]["Accurate crosses"])
        except:
            accurate_crosses_local.append(0)
        try:
            accurate_long_balls_local.append(subs_local[i]["stats"][1]["stats"]["Accurate long balls"])
        except:
            accurate_long_balls_local.append(0)
        try:
            dispossessed_local.append(subs_local[i]["stats"][1]["stats"]["Dispossessed"])
        except:
            dispossessed_local.append(0)
        try:
            tackles_won_local.append(subs_local[i]["stats"][2]["stats"]["Tackles won"])
        except:
            tackles_won_local.append(0)
        try:
            clearances_local.append(subs_local[i]["stats"][2]["stats"]["Clearances"])
        except:
            clearances_local.append(0)
        try:
            headed_clearances_local.append(subs_local[i]["stats"][2]["stats"]["Headed clearance"])
        except:
            headed_clearances_local.append(0)
        try:
            interceptions_local.append(subs_local[i]["stats"][2]["stats"]["Interceptions"])
        except:
            interceptions_local.append(0)
        try:
            recoveries_local.append(subs_local[i]["stats"][2]["stats"]["Recoveries"])
        except:
            recoveries_local.append(0)
        try:
            ground_duels_won_local.append(subs_local[i]["stats"][3]["stats"]["Ground duels won"])
        except:
            ground_duels_won_local.append(0)
        try:
            aerial_duels_won_local.append(subs_local[i]["stats"][3]["stats"]["Aerial duels won"])
        except:
            aerial_duels_won_local.append(0)
        try:
            was_fouled_local.append(subs_local[i]["stats"][3]["stats"]["Was fouled"])
        except:
            was_fouled_local.append(0)
        try:
            foules_committed_local.append(subs_local[i]["stats"][3]["stats"]["Fouls committed"])
        except:
            foules_committed_local.append(0)
        try:
            penalties_won_local.append(subs_local[i]["stats"][1]["stats"]["Penalties won"])
        except:
            penalties_won_local.append(0)
        try:
            corner_local.append(subs_local[i]["stats"][1]["stats"]["Corners"])
        except:
            corner_local.append(0)
            
    for z in range(0,5):
        id_match_V.append(match_id)
        fecha_V.append(fecha)
        id_team_V.append(team_id_V)
        equipo_V.append(equipo_visitante)
        away.append("away")
        away_player.append("suplente")
        nombre_visitante.append(subs_visitante[z]["name"]["lastName"])
        posicion_visitante.append(subs_visitante[z]["role"])
        shirt_visitante.append(subs_visitante[z]["shirt"])
        player_id_v.append(subs_visitante[z]["id"])
        try:
            minutes_visitante.append(subs_visitante[z]["minutesPlayed"])
        except:
            minutes_visitante.append(0)
        try:
            rating_visitante.append(subs_visitante[z]["stats"][0]["stats"]["FotMob rating"])
        except:
            rating_visitante.append(0)
        try:
            goals_visitante.append(subs_visitante[z]["stats"][0]["stats"]["Goals"])
        except:
            goals_visitante.append(0)
        try:
            assists_visitante.append(subs_visitante[z]["stats"][0]["stats"]["Assists"])
        except:
            assists_visitante.append(0)
        try:
            shots_visitante.append(subs_visitante[z]["stats"][0]["stats"]["Total shots"])
        except:
            shots_visitante.append(0)
        try:
            accurate_passes_visitante.append(subs_visitante[z]["stats"][0]["stats"]["Accurate passes"])
        except:
            accurate_passes_visitante.append(0)
        try:
            chances_created_visitante.append(subs_visitante[z]["stats"][0]["stats"]["Chances created"])
        except:
            chances_created_visitante.append(0)
        try:
            xg_visitante.append(subs_visitante[z]["stats"][0]["stats"]["Expected goals (xG)"])
        except:
            xg_visitante.append(0)
        try:
            xgot_visitante.append(subs_visitante[z]["stats"][0]["stats"]["Expected goals on target (xGOT)"])
        except:
            xgot_visitante.append(0)
        try:
            xa_visitante.append(subs_visitante[z]["stats"][0]["stats"]['Expected assists (xA)'])
        except:
            xa_visitante.append(0)
        try:
            blocked_shots_visitante.append(subs_visitante[z]["stats"][1]["stats"]["Blocked shots"])
        except:
            blocked_shots_visitante.append(0)
        try:
            touches_visitante.append(subs_visitante[z]["stats"][1]["stats"]["Touches"])
        except:
            touches_visitante.append(0)
        try:
            successful_dribbles_visitante.append(subs_visitante[z]["stats"][1]["stats"]["Successful dribbles"])
        except:
            successful_dribbles_visitante.append(0)
        try:
            passes_into_final_third_visitante.append(subs_visitante[z]["stats"][1]["stats"]["Passes into final third"])
        except:
            passes_into_final_third_visitante.append(0)
        try:
            accurate_crosses_visitante.append(subs_visitante[z]["stats"][1]["stats"]["Accurate crosses"])
        except:
            accurate_crosses_visitante.append(0)
        try:
            accurate_long_balls_visitante.append(subs_visitante[z]["stats"][1]["stats"]["Accurate long balls"])
        except:
            accurate_long_balls_visitante.append(0)
        try:
            dispossessed_visitante.append(subs_visitante[z]["stats"][1]["stats"]["Dispossessed"])
        except:
            dispossessed_visitante.append(0)
        try:
            tackles_won_visitante.append(subs_visitante[z]["stats"][2]["stats"]["Tackles won"])
        except:
            tackles_won_visitante.append(0)
        try:
            clearances_visitante.append(subs_visitante[z]["stats"][2]["stats"]["Clearances"])
        except:
            clearances_visitante.append(0)
        try:
            headed_clearances_visitante.append(subs_visitante[z]["stats"][2]["stats"]["Headed clearance"])
        except:
            headed_clearances_visitante.append(0)
        try:
            interceptions_visitante.append(subs_visitante[z]["stats"][2]["stats"]["Interceptions"])
        except:
            interceptions_visitante.append(0)
        try:
            recoveries_visitante.append(subs_visitante[z]["stats"][2]["stats"]["Recoveries"])
        except:
            recoveries_visitante.append(0)
        try:
            ground_duels_won_visitante.append(subs_visitante[z]["stats"][3]["stats"]["Ground duels won"])
        except:
            ground_duels_won_visitante.append(0)
        try:
            aerial_duels_won_visitante.append(subs_visitante[z]["stats"][3]["stats"]["Aerial duels won"])
        except:
            aerial_duels_won_visitante.append(0)
        try:
            was_fouled_visitante.append(subs_visitante[z]["stats"][3]["stats"]["Was fouled"])
        except:
            was_fouled_visitante.append(0)
        try:
            foules_committed_visitante.append(subs_visitante[z]["stats"][3]["stats"]["Fouls committed"])
        except:
            foules_committed_visitante.append(0)
        try:
            penalties_won_visitante.append(subs_visitante[z]["stats"][1]["stats"]["Penalties won"])
        except:
            penalties_won_visitante.append(0)
        try:
            corner_visitante.append(subs_visitante[z]["stats"][1]["stats"]["Corners"])
        except:
            corner_visitante.append(0)
            
         
    


    col_names = ["player_id","match_id","round","team_id","team","condition_team","condition_player","name","posicion",'shirt','minutes',"rating",'goals','assists','shots',"accurate passes","chances created","xg","xgot","xa","blocked shots","touches","successful dribbles","passes into final third","accurate crosses","accurate long balls","dispossessed","tackles won","clearances","headed clearances","interceptions","recoveries","ground duells won","aerial duels won","was fouled","foules committed","corners","penalties won"]
    individual_L = pd.DataFrame([player_id_l,id_match_L,fecha_L,id_team_L,equipo_L,home,home_player,nombre_local,posicion_local,shirt_local,minutes_local,rating_local,goals_local,assists_local,shots_local,accurate_passes_local,chances_created_local,xg_local,xgot_local,xa_local,blocked_shots_local,touches_local,successful_dribbles_local,passes_into_final_third_local,accurate_crosses_local,accurate_long_balls_local,dispossessed_local,tackles_won_local,clearances_local,headed_clearances_local,interceptions_local,recoveries_local,ground_duels_won_local,aerial_duels_won_local,was_fouled_local,foules_committed_local,corner_local,penalties_won_local], index = col_names)
    individual_L = individual_L.T
    individual_L

    individual_V = pd.DataFrame([player_id_v,id_match_V,fecha_V,id_team_V,equipo_V,away,away_player,nombre_visitante,posicion_visitante,shirt_visitante,minutes_visitante,rating_visitante,goals_visitante,assists_visitante,shots_visitante,accurate_passes_visitante,chances_created_visitante,xg_visitante,xgot_visitante,xa_visitante,blocked_shots_visitante,touches_visitante,successful_dribbles_visitante,passes_into_final_third_visitante,accurate_crosses_visitante,accurate_long_balls_visitante,dispossessed_visitante,tackles_won_visitante,clearances_visitante,headed_clearances_visitante,interceptions_visitante,recoveries_visitante,ground_duels_won_visitante,aerial_duels_won_visitante,was_fouled_visitante,foules_committed_visitante,corner_visitante,penalties_won_visitante], index = col_names)
    individual_V = individual_V.T
    
    
    


    for i in range(0,len(shots_data)):
        id_match.append(match_id)
        team.append(shots_data[i]["teamId"])
        player.append(shots_data[i]["playerName"])
        x.append(round(float(shots_data[i]["x"]),2))
        y.append(round(float(shots_data[i]["y"]),2))
        time.append(int(shots_data[i]["min"]))
        shot_type.append(shots_data[i]["shotType"])
        situation.append(shots_data[i]["situation"])
        period.append(shots_data[i]["period"])
        end_z.append(round(shots_data[i]["goalCrossedZ"],2))
        if (shots_data[i]["expectedGoals"])==None:
            xG.append(0)
        else:
            xG.append(round(float(shots_data[i]["expectedGoals"]),2))
        if (shots_data[i]["expectedGoalsOnTarget"]) == None:
            xGOT.append(0)
        else:
            xGOT.append(round(float(shots_data[i]["expectedGoalsOnTarget"]),2))
        if (shots_data[i]["blockedX"]) == None:
            end_x.append(0)
        else:
            end_x.append(round(float(shots_data[i]["blockedX"]),2))
        if (shots_data[i]["blockedY"]) == None or (shots_data[i]["eventType"]=="AttemptSaved") :
            end_y.append(round(shots_data[i]["goalCrossedY"],2))
        else:
            end_y.append(round(float(shots_data[i]["blockedY"]),2))
        if (shots_data[i]["isBlocked"])==True:
            result.append("Blocked")
        elif (shots_data[i]["isOwnGoal"])==True:
            result.append("Own Goal")
        else:
            result.append(shots_data[i]["eventType"])
        
                
    col_names_Shots = ["match_id",'player','team','x','y','endx','endy',"endz",'result','xg','xgot','time','situation',"period","shotType"]
    shots_df = pd.DataFrame([id_match,player,team,x,y,end_x,end_y,end_z,result,xG,xGOT,time,situation,period,shot_type], index = col_names_Shots)
    shots_df = shots_df.T

    individual=pd.concat([individual_L,individual_V],ignore_index=True).sort_values(["round","match_id","condition_team"],ignore_index=True)
    
    
  
    # Local team
    try:
        ball_possesion_general_local.append(stats_general[0]["stats"][0]["stats"][0])
    except:
        ball_possesion_general_local.append(0)

    try:
        xg_general_local.append(stats_general[0]["stats"][1]["stats"][0])
    except:
        xg_general_local.append(0)

    try:
        shots_general_local.append(stats_general[0]["stats"][2]["stats"][0])
    except:
        shots_general_local.append(0)

    try:
        big_chances_general_local.append(stats_general[0]["stats"][3]["stats"][0])
    except:
        big_chances_general_local.append(0)

    try:
        big_chances_missed_general_local.append(stats_general[0]["stats"][4]["stats"][0])
    except:
        big_chances_missed_general_local.append(0)

    try:
        accurate_passes_general_local.append(stats_general[0]["stats"][5]["stats"][0])
    except:
        accurate_passes_general_local.append(0)

    try:
        fouls_committed_general_local.append(stats_general[0]["stats"][6]["stats"][0])
    except:
        fouls_committed_general_local.append(0)

    try:
        offsides_general_local.append(stats_general[0]["stats"][7]["stats"][0])
    except:
        offsides_general_local.append(0)

    try:
        corners_general_local.append(stats_general[0]["stats"][8]["stats"][0])
    except:
        corners_general_local.append(0)

    try:
        shots_off_target_general_local.append(stats_general[1]["stats"][2]["stats"][0])
    except:
        shots_off_target_general_local.append(0)

    try:
        shots_on_target_general_local.append(stats_general[1]["stats"][3]["stats"][0])
    except:
        shots_on_target_general_local.append(0)

    try:
        blocked_shots_general_local.append(stats_general[1]["stats"][4]["stats"][0])
    except:
        blocked_shots_general_local.append(0)

    try:
        hit_woodwork_general_local.append(stats_general[1]["stats"][5]["stats"][0])
    except:
        hit_woodwork_general_local.append(0)

    try:
        shots_inside_box_general_local.append(stats_general[1]["stats"][6]["stats"][0])
    except:
        shots_inside_box_general_local.append(0)

    try:
        shots_outside_box_general_local.append(stats_general[1]["stats"][7]["stats"][0])
    except:
        shots_outside_box_general_local.append(0)

    try:
        xg_first_half_general_local.append(stats_general[2]["stats"][2]["stats"][0])
    except:
        xg_first_half_general_local.append(0)

    try:
        xg_second_half_general_local.append(stats_general[2]["stats"][3]["stats"][0])
    except:
        xg_second_half_general_local.append(0)

    try:
        xg_open_play_general_local.append(stats_general[2]["stats"][4]["stats"][0])
    except:
        xg_open_play_general_local.append(0)

    try:
        xg_set_play_general_local.append(stats_general[2]["stats"][5]["stats"][0])
    except:
        xg_set_play_general_local.append(0)

    try:
        xg_on_target_general_local.append(stats_general[2]["stats"][6]["stats"][0])
    except:
        xg_on_target_general_local.append(0)

    try:
        passes_general_local.append(stats_general[3]["stats"][1]["stats"][0])
    except:
        passes_general_local.append(0)



    try:
        passes_own_half_general_local.append(stats_general[3]["stats"][3]["stats"][0])
    except:
        passes_own_half_general_local.append(0)

    try:
        passes_opposition_half_general_local.append(stats_general[3]["stats"][4]["stats"][0])
    except:
        passes_opposition_half_general_local.append(0)

    try:
        passes_accurate_long_balls_general_local.append(stats_general[3]["stats"][5]["stats"][0])
    except:
        passes_accurate_long_balls_general_local.append(0)

    try:
        passes_accurate_crosses_general_local.append(stats_general[3]["stats"][6]["stats"][0])
    except:
        passes_accurate_crosses_general_local.append(0)

    try:
        passes_throws_general_local.append(stats_general[3]["stats"][7]["stats"][0])
    except:
        passes_throws_general_local.append(0)

    try:
        tackles_won_general_local.append(stats_general[4]["stats"][1]["stats"][0])
    except:
        tackles_won_general_local.append(0)

    try:
        interceptions_general_local.append(stats_general[4]["stats"][2]["stats"][0])
    except:
        interceptions_general_local.append(0)

    try:
        blocks_genera_locall.append(stats_general[4]["stats"][3]["stats"][0])
    except:
        blocks_genera_locall.append(0)

    try:
        clearances_general_local.append(stats_general[4]["stats"][4]["stats"][0])
    except:
        clearances_general_local.append(0)

    try:
        keeper_saves_general_local.append(stats_general[4]["stats"][5]["stats"][0])
    except:
        keeper_saves_general_local.append(0)

    try:
        duels_won_general_local.append(stats_general[5]["stats"][1]["stats"][0])
    except:
        duels_won_general_local.append(0)

    try:
        ground_duels_won_general_local.append(stats_general[5]["stats"][2]["stats"][0])
    except:
        ground_duels_won_general_local.append(0)

    try:
        aerial_duels_won_general_local.append(stats_general[5]["stats"][3]["stats"][0])
    except:
        aerial_duels_won_general_local.append(0)

    try:
        successful_dribbles_general_local.append(stats_general[5]["stats"][4]["stats"][0])
    except:
        successful_dribbles_general_local.append(0)

    try:
        yellow_cards_genera_locall.append(stats_general[6]["stats"][1]["stats"][0])
    except:
        yellow_cards_genera_locall.append(0)

    try:
        red_cards_general_local.append(stats_general[6]["stats"][2]["stats"][0])
    except:
        red_cards_general_local.append(0)


    fecha_equipo.append(fecha)
    match_id_general.append(match_id)
    local_general.append(equipo_local)
    visitante_general.append(equipo_visitante)
    
   
    # Visiting team
    try:
        ball_possesion_general_visitante.append(stats_general[0]["stats"][0]["stats"][1])
    except:
        ball_possesion_general_visitante.append(0)

    try:
        xg_general_visitante.append(stats_general[0]["stats"][1]["stats"][1])
    except:
        xg_general_visitante.append(0)

    try:
        shots_general_visitante.append(stats_general[0]["stats"][2]["stats"][1])
    except:
        shots_general_visitante.append(0)

    try:
        big_chances_general_visitante.append(stats_general[0]["stats"][3]["stats"][1])
    except:
        big_chances_general_visitante.append(0)

    try:
        big_chances_missed_general_visitante.append(stats_general[0]["stats"][4]["stats"][1])
    except:
        big_chances_missed_general_visitante.append(0)

    try:
        accurate_passes_general_visitante.append(stats_general[0]["stats"][5]["stats"][1])
    except:
        accurate_passes_general_visitante.append(0)

    try:
        fouls_committed_general_visitante.append(stats_general[0]["stats"][6]["stats"][1])
    except:
        fouls_committed_general_visitante.append(0)

    try:
        offsides_general_visitante.append(stats_general[0]["stats"][7]["stats"][1])
    except:
        offsides_general_visitante.append(0)

    try:
        corners_general_visitante.append(stats_general[0]["stats"][8]["stats"][1])
    except:
        corners_general_visitante.append(0)

    try:
        shots_off_target_general_visitante.append(stats_general[1]["stats"][2]["stats"][1])
    except:
        shots_off_target_general_visitante.append(0)

    try:
        shots_on_target_general_visitante.append(stats_general[1]["stats"][3]["stats"][1])
    except:
        shots_on_target_general_visitante.append(0)

    try:
        blocked_shots_general_visitante.append(stats_general[1]["stats"][4]["stats"][1])
    except:
        blocked_shots_general_visitante.append(0)

    try:
        hit_woodwork_general_visitante.append(stats_general[1]["stats"][5]["stats"][1])
    except:
        hit_woodwork_general_visitante.append(0)

    try:
        shots_inside_box_general_visitante.append(stats_general[1]["stats"][6]["stats"][1])
    except:
        shots_inside_box_general_visitante.append(0)

    try:
        shots_outside_box_general_visitante.append(stats_general[1]["stats"][7]["stats"][1])
    except:
        shots_outside_box_general_visitante.append(0)

    try:
        xg_first_half_general_visitante.append(stats_general[2]["stats"][2]["stats"][1])
    except:
        xg_first_half_general_visitante.append(0)

    try:
        xg_second_half_general_visitante.append(stats_general[2]["stats"][3]["stats"][1])
    except:
        xg_second_half_general_visitante.append(0)

    try:
        xg_open_play_general_visitante.append(stats_general[2]["stats"][4]["stats"][1])
    except:
        xg_open_play_general_visitante.append(0)

    try:
        xg_set_play_general_visitante.append(stats_general[2]["stats"][5]["stats"][1])
    except:
        xg_set_play_general_visitante.append(0)

    try:
        xg_on_target_general_visitante.append(stats_general[2]["stats"][6]["stats"][1])
    except:
        xg_on_target_general_visitante.append(0)
        
    # Visiting team
    try:
        passes_general_visitante.append(stats_general[3]["stats"][1]["stats"][1])
    except:
        passes_general_visitante.append(0)

    try:
        passes_own_half_general_visitante.append(stats_general[3]["stats"][3]["stats"][1])
    except:
        passes_own_half_general_visitante.append(0)

    try:
        passes_opposition_half_general_visitante.append(stats_general[3]["stats"][4]["stats"][1])
    except:
        passes_opposition_half_general_visitante.append(0)

    try:
        passes_accurate_long_balls_general_visitante.append(stats_general[3]["stats"][5]["stats"][1])
    except:
        passes_accurate_long_balls_general_visitante.append(0)

    try:
        passes_accurate_crosses_general_visitante.append(stats_general[3]["stats"][6]["stats"][1])
    except:
        passes_accurate_crosses_general_visitante.append(0)

    try:
        passes_throws_general_visitante.append(stats_general[3]["stats"][7]["stats"][1])
    except:
        passes_throws_general_visitante.append(0)

    try:
        tackles_won_general_visitante.append(stats_general[4]["stats"][1]["stats"][1])
    except:
        tackles_won_general_visitante.append(0)

    try:
        interceptions_general_visitante.append(stats_general[4]["stats"][2]["stats"][1])
    except:
        interceptions_general_visitante.append(0)

    try:
        blocks_general_visitante.append(stats_general[4]["stats"][3]["stats"][1])
    except:
        blocks_general_visitante.append(0)

    try:
        clearances_general_visitante.append(stats_general[4]["stats"][4]["stats"][1])
    except:
        clearances_general_visitante.append(0)

    try:
        keeper_saves_general_visitante.append(stats_general[4]["stats"][5]["stats"][1])
    except:
        keeper_saves_general_visitante.append(0)

    try:
        duels_won_general_visitante.append(stats_general[5]["stats"][1]["stats"][1])
    except:
        duels_won_general_visitante.append(0)

    try:
        ground_duels_won_general_visitante.append(stats_general[5]["stats"][2]["stats"][1])
    except:
        ground_duels_won_general_visitante.append(0)

    try:
        aerial_duels_won_general_visitante.append(stats_general[5]["stats"][3]["stats"][1])
    except:
        aerial_duels_won_general_visitante.append(0)

    try:
        successful_dribbles_general_visitante.append(stats_general[5]["stats"][4]["stats"][1])
    except:
        successful_dribbles_general_visitante

    try:
        yellow_cards_general_visitante.append(stats_general[6]["stats"][1]["stats"][1])
    except:
        yellow_cards_general_visitante.append(0)

    try:
        red_cards_general_visitante.append(stats_general[6]["stats"][2]["stats"][1])
    except:
        red_cards_general_visitante.append(0)


    col_names_general = ["fecha","match_id","equipo","ball possesion","xg","shots","big chances","big chances missed","accurate passes","fouls commited","offsides","corners","shots off target","shots on target","blocked shots","hit woodwork","shots inside box","shots outside box", "xg first half", "xg second half","xg open play","xg set play","xgot","passes","own half","opposition half","accurate long balls","accurate crosses","throws","tackles won","interceptions","blocks","clearances","keeper saves","duels won","ground duels won","aerial duels won","successful dribbles","yellow cards","red cards"]
    general_L = pd.DataFrame([fecha_equipo,match_id_general,local_general,ball_possesion_general_local,xg_general_local,shots_general_local,big_chances_general_local,big_chances_missed_general_local,accurate_passes_general_local,fouls_committed_general_local,offsides_general_local,corners_general_local,shots_off_target_general_local,shots_on_target_general_local,blocked_shots_general_local,hit_woodwork_general_local,shots_inside_box_general_local,shots_outside_box_general_local,xg_first_half_general_local,xg_second_half_general_local,xg_open_play_general_local,xg_set_play_general_local,xg_on_target_general_local,passes_general_local,passes_own_half_general_local,passes_opposition_half_general_local,passes_accurate_long_balls_general_local,passes_accurate_crosses_general_local,passes_throws_general_local,tackles_won_general_local,interceptions_general_local,blocks_genera_locall,clearances_general_local,keeper_saves_general_local,duels_won_general_local,ground_duels_won_general_local,aerial_duels_won_general_local,successful_dribbles_general_local,yellow_cards_genera_locall,red_cards_general_local], index = col_names_general)
    general_L = general_L.T
    general_V = pd.DataFrame([fecha_equipo,match_id_general,visitante_general,ball_possesion_general_visitante,xg_general_visitante,shots_general_visitante,big_chances_general_visitante,big_chances_missed_general_visitante,accurate_passes_general_visitante,fouls_committed_general_visitante,offsides_general_visitante,corners_general_visitante,shots_off_target_general_visitante,shots_on_target_general_visitante,blocked_shots_general_visitante,hit_woodwork_general_visitante,shots_inside_box_general_visitante,shots_outside_box_general_visitante,xg_first_half_general_visitante,xg_second_half_general_visitante,xg_open_play_general_visitante,xg_set_play_general_visitante,xg_on_target_general_visitante,passes_general_visitante,passes_own_half_general_visitante,passes_opposition_half_general_visitante,passes_accurate_long_balls_general_visitante,passes_accurate_crosses_general_visitante,passes_throws_general_visitante,tackles_won_general_visitante,interceptions_general_visitante,blocks_general_visitante,clearances_general_visitante,keeper_saves_general_visitante,duels_won_general_visitante,ground_duels_won_general_visitante,aerial_duels_won_general_visitante,successful_dribbles_general_visitante,yellow_cards_general_visitante,red_cards_general_visitante], index = col_names_general)
    general_V = general_V.T
    #resultados_elegido=ligas[(ligas["Equipo Local"]==equipo)|(ligas["Equipo Visitante"]==equipo)]
    general=pd.concat([general_L,general_V],ignore_index=True).sort_values(["fecha","match_id"],ignore_index=True)

# %%
partido_unico=ligas["Match Id"].unique()
nombre_partido=ligas["Partido"].unique()
ayuda_partido=pd.DataFrame()
ayuda_partido["matchid"]=partido_unico
ayuda_partido["match_name"]=nombre_partido

# %%
general_2=pd.merge(general,ayuda_partido,left_on=["match_id"], right_on="matchid",how="left")

# %%
individual_2=pd.merge(individual,ayuda_partido,left_on=["match_id"], right_on="matchid",how="left")

# %%
dict_columns = [col for col in individual_2.columns if isinstance(individual_2[col].iloc[0], dict)]

# %%
dict_columns
# Out:
# ['rating',
#  'goals',
#  'assists',
#  'shots',
#  'accurate passes',
#  'chances created',
#  'xg',
#  'xa',
#  'blocked shots',
#  'touches',
#  'successful dribbles',
#  'passes into final third',
#  'accurate crosses',
#  'dispossessed',
#  'tackles won',
#  'recoveries',
#  'ground duells won',
#  'aerial duels won',
#  'was fouled',
#  'foules committed']

# %%
individual_2 = individual_2.applymap(lambda x: x['value'] if isinstance(x, dict) else x)

# %%
individual_2.head()
# Out:
#   player_id match_id round  team_id        team condition_team  \
# 0   1065653  3887285     1   8410.0  Randers FC           away
# 1    205844  3887285     1   8410.0  Randers FC           away
# 2    180467  3887285     1   8410.0  Randers FC           away
# 3   1034139  3887285     1   8410.0  Randers FC           away
# 4    525592  3887285     1   8410.0  Randers FC           away
#
#   condition_player          name    posicion  shirt  minutes  rating  goals  \
# 0          titular       Kehinde  Midfielder   10.0     73.0    6.18    0.0
# 1          titular  Brock-Madsen  Midfielder   44.0     59.0    5.68    0.0
# 2          titular      Ankersen  Midfielder    9.0     88.0    7.08    0.0
# 3          titular    Kristensen    Defender   19.0     90.0    6.84    0.0
# 4          titular     Lauenborg  Midfielder   14.0     90.0    7.68    0.0
#
#    assists  shots accurate passes  chances created    xg  xgot    xa  \
# ...

# %%
formaciones=individual_2[individual_2.condition_player=="titular"][["condition_player","name","shirt","posicion","team"]].sort_values(["team","shirt"])

# %%
formaciones
# Out:
#      condition_player            name  shirt    posicion          team
# 1650          titular          Beijmo    2.0    Defender    AGF Aarhus
# 1812          titular          Beijmo    2.0    Defender    AGF Aarhus
# 2170          titular          Beijmo    2.0    Defender    AGF Aarhus
# 2398          titular          Beijmo    2.0    Defender    AGF Aarhus
# 2530          titular          Beijmo    2.0    Defender    AGF Aarhus
# 127           titular         Bisseck    4.0    Defender    AGF Aarhus
# 343           titular         Bisseck    4.0    Defender    AGF Aarhus
# 481           titular         Bisseck    4.0    Defender    AGF Aarhus
# 551           titular         Bisseck    4.0    Defender    AGF Aarhus
# 751           titular         Bisseck    4.0    Defender    AGF Aarhus
# 911           titular         Bisseck    4.0    Defender    AGF Aarhus
# 1134          titular         Bisseck    4.0    Defender    AGF Aarhus
# ...

# %%
individual_2["player_id"] = pd.to_numeric(individual_2["player_id"], errors='coerce').fillna(-1).astype(int)

# %%
unique_player_id = np.unique(individual_2["player_id"].astype(int))

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd



name = []
team = []
player_id = []
position = []
height = []
age = []
country = []
foot = []
shirt = []

for i in list(unique_player_id)[1:700]:
    if i==1467546:
        continue
    else:
        URL=f"https://www.fotmob.com/players/{i}"

        r = requests.get(URL)
        html_doc = r.text
        soup = BeautifulSoup(html_doc, "html.parser")

        datos = json.loads(soup.find("script", attrs={"id": "__NEXT_DATA__"}).text)

        try:
            name.append(datos["props"]["pageProps"]["data"]["name"])
        except:
            name.append(None)
        try:
            team.append(datos["props"]["pageProps"]["data"]["origin"]["teamName"])
        except:
            team.append(None)
        player_id.append(i)
        try:
            position.append(datos["props"]["pageProps"]["data"]["origin"]["positionDesc"]["positions"][0]["strPos"]["label"])
        except:
            position.append("N/A")

        for j in range(len(datos["props"]["pageProps"]["data"]["playerProps"])):
            if datos["props"]["pageProps"]["data"]["playerProps"][j]["title"]=="Height":
                height.append(datos["props"]["pageProps"]["data"]["playerProps"][j]["value"]["fallback"])
            elif datos["props"]["pageProps"]["data"]["playerProps"][j]["title"]=="Age":
                age.append(datos["props"]["pageProps"]["data"]["playerProps"][j]["value"]["fallback"])
            elif datos["props"]["pageProps"]["data"]["playerProps"][j]["title"]=="Country":
                country.append(datos["props"]["pageProps"]["data"]["playerProps"][j]["value"]["fallback"])
            elif datos["props"]["pageProps"]["data"]["playerProps"][j]["title"]=="Preferred foot":
                foot.append(datos["props"]["pageProps"]["data"]["playerProps"][j]["value"]["fallback"])
            elif datos["props"]["pageProps"]["data"]["playerProps"][j]["title"]=="Shirt":
                shirt.append(datos["props"]["pageProps"]["data"]["playerProps"][j]["value"]["fallback"])

        # Add placeholders for missing data if necessary
        if len(shirt) < len(player_id):
            shirt.append(None)
        if len(height) < len(player_id):
            height.append(None)
        if len(age) < len(player_id):
            age.append(None)
        if len(country) < len(player_id):
            country.append(None)
        if len(foot) < len(player_id):
            foot.append(None)

# Create dataframe
df = pd.DataFrame({"player id": player_id,
                   'name': name,
                   'team': team,
                   'position': position,
                   'height': height,
                   'age': age,
                   'country': country,
                   'foot': foot,
                   'shirt': shirt})

# %%
df.head()
# Out:
#    player id               name           team              position  height  \
# 0      11798               Zeca  Panathinaikos  Defensive Midfielder  177 cm
# 1      31241   Henrik Dalsgaard    Midtjylland            Right Back  192 cm
# 2      41036    Janus Drachmann           None    Central Midfielder  179 cm
# 3      47532      Martin Hansen         Odense                Keeper  188 cm
# 4      62329  Patrick Mortensen     AGF Aarhus        Center Forward  188 cm
#
#    age  country   foot  shirt
# 0   34   Greece   Both    6.0
# 1   33  Denmark  Right   14.0
# 2   35  Denmark  Right    NaN
# 3   33  Denmark   Both    1.0
# 4   33  Denmark  Right    9.0

# %%
unicos=dinamarca["Match Id"].unique()

# %%
id_unico=individual["team_id"].unique()
team_unico=individual["team"].unique()

ayuda_equipo=pd.DataFrame()
ayuda_equipo["team_id"]=id_unico
ayuda_equipo["team_name"]=team_unico

# %%
shots_df_2=pd.merge(shots_df,ayuda_equipo,left_on=["team"], right_on="team_id",how="left")

# %%
goals=shots_df_2[(shots_df_2["result"]=="Goal")].reset_index()

# %%
goals_2=pd.merge(goals,dinamarca,left_on="match_id",right_on="Match Id")

# %%
goles_por_matchid=goals_2["match_id"].value_counts()

# %%
resultado=[]
n=0
k=0
for i in range(1,len(goals_2)):
        if (goals_2["team_name"][i]==goals_2["Equipo Local"][i]) & (goals_2["match_id"][i-1]==goals_2["match_id"][i]):
            n+=1 
            resultado.append([n,k])
        elif (goals_2["team_name"][i]==goals_2["Equipo Visitante"][i])& (goals_2["match_id"][i-1]==goals_2["match_id"][i]):
            k+=1
            resultado.append([n,k])
        elif (goals_2["team_name"][i]==goals_2["Equipo Local"][i]) & (goals_2["match_id"][i-1]!=goals_2["match_id"][i]):
            n=0
            k=0
            n+=1
            resultado.append([n,k])
        elif (goals_2["team_name"][i]==goals_2["Equipo Visitante"][i]) & (goals_2["match_id"][i-1]!=goals_2["match_id"][i]):
            n=0
            k=0
            k+=1
            resultado.append([n,k])

# %%
#agrego el primer resultado que no me tomó
resultado.insert(0,[1,0])

# %%
goals_2["Resultado"]=resultado

# %%
goles_por_matchid=goals_2["match_id"].value_counts()

# %%
def foo(s1):
    return "{}".format(s1)

# %%
def comoVa(tiempo, matchId):
    if matchId not in unicos:
        return [0, 0]
    else:
        relevant_goals = goals_2[(goals_2["match_id"] == matchId) & (goals_2["time"] <= tiempo)]
        if len(relevant_goals) == 0:
            return [0, 0]
        else:
            latest_goal = relevant_goals.iloc[-1]
            return latest_goal["Resultado"]

# %%
def quienGana(tiempo,matchId):
        if comoVa(tiempo,matchId)[0]==comoVa(tiempo,matchId)[1]:
            return "Empatan"
        elif comoVa(tiempo,matchId)[0]>comoVa(tiempo,matchId)[1]:
            return ligas[ligas["Match Id"]==matchId]["Equipo Local"].reset_index()["Equipo Local"][0]
        elif comoVa(tiempo,matchId)[1]>comoVa(tiempo,matchId)[0]:
            return ligas[ligas["Match Id"]==matchId]["Equipo Visitante"].reset_index()["Equipo Visitante"][0]

# %%
def dieronVuelta(matchId):
    if matchId not in unicos:
        return "No"
    elif quienGana(100,matchId)=="Empatan":
        return "No"
    elif goals_2[goals_2["Match Id"]==matchId]["team_name"].reset_index()["team_name"][0]!=quienGana(100,matchId):
        return "Si"
    elif goals_2[goals_2["Match Id"]==matchId]["team_name"].reset_index()["team_name"][0]==quienGana(100,matchId):
        return "No"

# %%
def partidosDioVuelta(nombreEquipo):
    partidosGanados = []
    partidosPerdidos = []
    for matchId in unicos[1:]:
        resultado = dieronVuelta(str(matchId))
        if resultado == "Si":
            equipoLocal = ligas.loc[ligas["Match Id"] == str(matchId), "Equipo Local"].iloc[0]
            equipoVisitante = ligas.loc[ligas["Match Id"] == str(matchId), "Equipo Visitante"].iloc[0]
            if nombreEquipo == equipoLocal:
                if quienGana(100, matchId) == nombreEquipo:
                    partidosGanados.append(matchId)
                else:
                    partidosPerdidos.append(matchId)
            elif nombreEquipo == equipoVisitante:
                if quienGana(100, matchId) == nombreEquipo:
                    partidosGanados.append(matchId)
                else:
                    partidosPerdidos.append(matchId)
    return partidosGanados, partidosPerdidos

# %%
def partidosDioVuelta(nombreEquipo):
    partidosGanados = []
    partidosPerdidos = []
    
    for matchId in unicos[1:]:
        resultado = dieronVuelta(str(matchId))
        
        if resultado == "Si":
            equipoLocal = ligas.loc[ligas["Match Id"] == str(matchId), "Equipo Local"].iloc[0]
            equipoVisitante = ligas.loc[ligas["Match Id"] == str(matchId), "Equipo Visitante"].iloc[0]
            
            if nombreEquipo == equipoLocal:
                if quienGana(100, matchId) == nombreEquipo:
                    partidosGanados.append(equipoVisitante)
                else:
                    partidosPerdidos.append(equipoVisitante)
            
            elif nombreEquipo == equipoVisitante:
                if quienGana(100, matchId) == nombreEquipo:
                    partidosGanados.append(equipoLocal)
                else:
                    partidosPerdidos.append(equipoLocal)
    
    return partidosGanados, partidosPerdidos

# %%
ligas[ligas["Match Id"]==str(3887286)]["Equipo Local"].reset_index()["Equipo Local"][0]
# Out:
# 'Viborg'

# %%
def resultadosEntreEquipos(nombreEquipo1, nombreEquipo2):
    resultados = []
    
    for matchId in unicos[1:]:
        equipoLocal = ligas.loc[ligas["Match Id"] == str(matchId), "Equipo Local"].iloc[0]
        equipoVisitante = ligas.loc[ligas["Match Id"] == str(matchId), "Equipo Visitante"].iloc[0]
        resultado = ligas.loc[ligas["Match Id"] == str(matchId), "Resultado"].iloc[0]
        
        if (equipoLocal == nombreEquipo1 and equipoVisitante == nombreEquipo2) or (equipoLocal == nombreEquipo2 and equipoVisitante == nombreEquipo1):
            resultados.append(resultado)
    
    return resultados

# %%
nombreEquipo = "FC København"
partidos = partidosDioVuelta(nombreEquipo)
print(partidos)
# Out:
# (['Horsens'], ['Viborg', 'Randers FC'])

# %%
resultadosEntreEquipos("FC København","Aalborg BK")
# Out:
# [[1, 3], [1, 0]]
